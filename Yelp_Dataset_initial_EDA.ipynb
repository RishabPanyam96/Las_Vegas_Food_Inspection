# %%
import pandas as pd
import numpy as np

# %%
business_Data = pd.read_json('D:/down/yelpdataset/business.json',lines =True)

# %%
business_Data.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# ...

# %%
business_Data.shape
# Out:
# (192609, 14)

# %%
business_Data.columns
# Out:
# Index(['address', 'attributes', 'business_id', 'categories', 'city', 'hours',
#        'is_open', 'latitude', 'longitude', 'name', 'postal_code',
#        'review_count', 'stars', 'state'],
#       dtype='object')

# %%
business_Data.groupby('city')['city'].count().sort_values(ascending=False)[0:20]
# Out:
# city
# Las Vegas          29370
# Toronto            18906
# Phoenix            18766
# Charlotte           9509
# Scottsdale          8837
# Calgary             7736
# Pittsburgh          7017
# Montr̩al           6449
# Mesa                6080
# Henderson           4892
# Tempe               4550
# Chandler            4309
# Cleveland           3605
# Glendale            3543
# Madison             3494
# Gilbert             3462
# Mississauga         3112
# Peoria              1919
# Markham             1766
# North Las Vegas     1548
# Name: city, dtype: int64

# %%
business_Data.groupby('city')['city'].count().sort_values(ascending=False)
# Out:
# city
# Las Vegas                  29370
# Toronto                    18906
# Phoenix                    18766
# Charlotte                   9509
# Scottsdale                  8837
# Calgary                     7736
# Pittsburgh                  7017
# Montr̩al                   6449
# Mesa                        6080
# Henderson                   4892
# Tempe                       4550
# Chandler                    4309
# Cleveland                   3605
# Glendale                    3543
# Madison                     3494
# Gilbert                     3462
# Mississauga                 3112
# Peoria                      1919
# Markham                     1766
# North Las Vegas             1548
# Champaign                   1262
# North York                  1205
# Surprise                    1148
# Scarborough                 1103
# Richmond Hill               1026
# Brampton                    1002
# Concord                      990
# Vaughan                      919
# ...

# %%
business_Data.groupby('state')['state'].count().sort_values(ascending=False)
# Out:
# state
# AZ     56686
# NV     36312
# ON     33412
# NC     14720
# OH     14697
# PA     11216
# QC      9219
# AB      8012
# WI      5154
# IL      1932
# SC      1162
# NY        22
# CA        19
# TX         6
# FL         4
# XGM        4
# CT         3
# AL         3
# WA         3
# AK         2
# GA         2
# XWY        2
# NE         2
# VA         2
# VT         2
# NM         1
# DUR        1
# DOW        1
# TN         1
# CON        1
# UT         1
# BC         1
# BAS        1
# AR         1
# XGL        1
# NJ         1
# Name: state, dtype: int64

# %%
las_isn1 = pd.read_csv('D:/down/restaurant-inspections-1.csv')

# %%
las_isn1.shape
# Out:
# (148335, 23)

# %%
las_isn1['Inspection Date'] =pd.to_datetime(las_isn1['Inspection Date'])

# %%
las_isn1['Inspection Date'].min()
# Out:
# Timestamp('2010-01-01 00:00:00')

# %%
las_isn2 = pd.read_csv('D:/down/Restaurant_Inspections_Open_Data.csv')

# %%
las_isn2.columns
# Out:
# Index(['Serial_Number', 'Permit_Number', 'Restaurant_Name', 'Location_Name',
#        'Category_Name', 'Address', 'City', 'State', 'Zip', 'Current_Demerits',
#        'Current_Grade', 'Date_Current', 'Inspection_Date', 'Inspection_Time',
#        'Employee_ID', 'Inspection_Type', 'Inspection_Demerits',
#        'Inspection_Grade', 'Permit_Status', 'Inspection_Result', 'Violations',
#        'Record_Updated', 'Location_1', 'ObjectId'],
#       dtype='object')

# %%
las_isn2['Inspection_Date'] =pd.to_datetime(las_isn2['Inspection_Date'])

# %%
las_isn2['Inspection_Date'].min()
# Out:
# Timestamp('2019-06-21 00:00:00+0000', tz='UTC')

# %%
reader = pd.read_json('D:/down/yelpdataset/review.json',chunksize=20000,lines = True)

# %%
reader

# %%
df_reviews = pd.DataFrame(columns= ['review_id','user_id','business_id','stars','date','text','useful','funny','cool'])

# %%
df_reviews
# Out:
# Empty DataFrame
# Columns: [review_id, user_id, business_id, stars, date, text, useful, funny, cool]
# Index: []

# %%
df_new = pd.concat(reader,ignore_index =True)

# %%
df_new.shape
# Out:
# (6685900, 9)

# %%
df_new.head()
# Out:
#               business_id  cool                date  funny  \
# 0  ujmEBvifdJM6h6RLv4wQIg     0 2013-05-07 04:34:36      1
# 1  NZnhc2sEQy3RmzKTZnqtwQ     0 2017-01-14 21:30:33      0
# 2  WTqjgwHlXbSFevF32_DJVw     0 2016-11-09 20:09:03      0
# 3  ikCg8xy5JIg_NGPx-MSIDA     0 2018-01-09 20:56:38      0
# 4  b1b1eb3uo-w561D0ZfCEiQ     0 2018-01-30 23:07:38      0
#
#                 review_id  stars  \
# 0  Q1sbwvVQXV2734tPgoKj4Q      1
# 1  GJXCdrto3ASJOqKeVWPi6Q      5
# 2  2TzJjDVDEuAW6MR5Vuc1ug      5
# 3  yi0R0Ugj_xUx_Nek0-_Qig      5
# 4  11a8sVPMUFtaC7_ABRkmtw      1
#
#                                                 text  useful  \
# 0  Total bill for this horrible service? Over $8G...       6
# 1  I *adore* Travis at the Hard Rock's new Kelly ...       0
# 2  I have to say that this office really has it t...       3
# 3  Went in for a lunch. Steak sandwich was delici...       0
# 4  Today was my second out of three sessions I ha...       7
#
#                   user_id
# ...

# %%
Vegas_Data=business_Data[business_Data['city'] == 'Las Vegas']

# %%
Vegas_Data.shape
# Out:
# (29370, 14)

# %%
Reviews_Data = pd.merge(left=Vegas_Data,right =df_new,how='inner',left_on = 'business_id',right_on='business_id')

# %%
Reviews_Data.shape
# Out:
# (2030798, 22)

# %%
Reviews_Data.columns
# Out:
# Index(['address', 'attributes', 'business_id', 'categories', 'city', 'hours',
#        'is_open', 'latitude', 'longitude', 'name', 'postal_code',
#        'review_count', 'stars_x', 'state', 'cool', 'date', 'funny',
#        'review_id', 'stars_y', 'text', 'useful', 'user_id'],
#       dtype='object')

# %%
Reviews_Data['date'] = pd.to_datetime(Reviews_Data['date'])

# %%
Reviews_Data['date'].max()
# Out:
# Timestamp('2018-11-14 18:12:40')

# %%
Reviews_Data['date'].describe()
# Out:
# count                 2030798
# unique                2018217
# top       2014-10-24 03:56:24
# freq                        5
# first     2004-10-19 02:46:40
# last      2018-11-14 18:12:40
# Name: date, dtype: object

# %%
Reviews_Data.head()
# Out:
#                                 address  \
# 0  4545 E Tropicana Rd Ste 8, Tropicana
# 1  4545 E Tropicana Rd Ste 8, Tropicana
# 2  4545 E Tropicana Rd Ste 8, Tropicana
# 3          1775 E Tropicana Ave, Ste 29
# 4          1775 E Tropicana Ave, Ste 29
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
# 1  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
# 2  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
# 3  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...  PZ-LZzSlhSe9utkQYU8pFg
# 4  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...  PZ-LZzSlhSe9utkQYU8pFg
#
#                                           categories       city  \
# 0  Hair Salons, Hair Stylists, Barbers, Men's Hai...  Las Vegas
# 1  Hair Salons, Hair Stylists, Barbers, Men's Hai...  Las Vegas
# ...

# %%
Inspection_Data = pd.read_csv('D:/down/Isnpection_Data.csv')

# %%
Inspection_Data.columns
# Out:
# Index(['serial_number', 'permit_number', 'facility_id_x', 'owner_id_x',
#        'inspection_date', 'inspection_time', 'employee_id',
#        'inspection_type_id', 'inspection_demerits', 'inspection_grade',
#        'inspection_grade_new', 'permit_status', 'inspection_result',
#        'violations', 'record_updated', 'Unnamed: 15', 'Year', 'facility_id_y',
#        'owner_id_y', 'PE', 'restaurant_name', 'location_name', 'address',
#        'latitude', 'longitude', 'city_id', 'city_name', 'zip_code', 'nciaa',
#        'plan_review', 'record_status', 'current_grade', 'current_demerits',
#        'date_current', 'previous_grade', 'date_previous', 'search_text',
#        'Unnamed: 21'],
#       dtype='object')

# %%
Inspection_Data['longitude'].value_counts().count()
# Out:
# 7092

# %%
Inspection_Data.groupby(['latitude','longitude'])['facility_id_x'].count()
# Out:
# latitude   longitude
# 35.630520  -105.202103      2
# 35.933672  -115.189207      4
# 35.954400  -115.093590      3
# 35.968829  -115.189129     37
# 35.970045  -115.167126     24
# 35.970580  -115.166830      1
# 35.970741  -115.166721      1
# 35.971170  -115.164261      5
# 35.972277  -115.172820     35
# 35.972332  -115.193549    106
# 35.973171  -115.182206     45
# 35.973900  -115.160960      5
# 35.974815  -115.159645      2
# 35.974827  -115.159658     10
# 35.976557  -115.183785      5
# 35.980442  -115.186784     16
# 35.982296  -115.189991      2
# 35.982887  -115.190313     13
# 35.982936  -115.190839     19
# 35.983265  -115.159200     28
# 35.983669  -115.190162      6
# 35.987108  -115.257979      6
# 35.987733  -115.257634     20
# 35.988111  -115.141159      2
# 35.989403  -115.221252     30
# 35.990691  -115.154774     41
# 35.991203  -115.204015     14
# 35.991282  -115.182373      3
# 35.992811  -115.238182     74
# 35.993008  -115.507711     32
# ...

# %%
test = Inspection_Data.address[0]

# %%
test_data=Inspection_Data.loc[Inspection_Data['address'] == test,['address','latitude','longitude','facility_id_x']]

# %%
test_data.groupby('facility_id_x')['facility_id_x'].count()
# Out:
# facility_id_x
# FA0002435    1985
# FA0005176     675
# FA0007538     123
# FA0009986      27
# FA0010157      10
# FA0011449       4
# FA0072506       6
# Name: facility_id_x, dtype: int64

# %%
Reviews_Data[Reviews_Data['address']== test]
# Out:
#                        address  \
# 124499   3570 S Las Vegas Blvd
# 124500   3570 S Las Vegas Blvd
# 124501   3570 S Las Vegas Blvd
# 124502   3570 S Las Vegas Blvd
# 124503   3570 S Las Vegas Blvd
# 124504   3570 S Las Vegas Blvd
# 124505   3570 S Las Vegas Blvd
# 124506   3570 S Las Vegas Blvd
# 124507   3570 S Las Vegas Blvd
# 124508   3570 S Las Vegas Blvd
# 124509   3570 S Las Vegas Blvd
# 124510   3570 S Las Vegas Blvd
# 124511   3570 S Las Vegas Blvd
# 124512   3570 S Las Vegas Blvd
# 147016   3570 S Las Vegas Blvd
# 147017   3570 S Las Vegas Blvd
# 147018   3570 S Las Vegas Blvd
# 147019   3570 S Las Vegas Blvd
# 147020   3570 S Las Vegas Blvd
# 147021   3570 S Las Vegas Blvd
# 147022   3570 S Las Vegas Blvd
# 147023   3570 S Las Vegas Blvd
# 147024   3570 S Las Vegas Blvd
# 147025   3570 S Las Vegas Blvd
# 147026   3570 S Las Vegas Blvd
# 147027   3570 S Las Vegas Blvd
# 147028   3570 S Las Vegas Blvd
# 147029   3570 S Las Vegas Blvd
# 147030   3570 S Las Vegas Blvd
# ...
