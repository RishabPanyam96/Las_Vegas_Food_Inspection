# %%
import pandas as pd

# %%
ins = pd.read_csv(r"C:/Users/abdul/Desktop/Inspections_combination_done.csv")

# %%
ins.head(20)
# Out:
#    serial_number permit_number facility_id_x inspection_date  inspection_time  \
# 0      DA0001121     PR0000411     FA0002433      2005-03-25       1111746000
# 1      DA0001122     PR0000411     FA0002433      2005-11-07       1131360000
# 2      DA0001123     PR0000411     FA0002433      2005-11-18       1132314000
# 3      DA0001124     PR0000411     FA0002433      2006-09-25       1159179900
# 4      DA0001125     PR0000411     FA0002433      2007-07-25       1185371400
# 5      DA0001128     PR0000411     FA0002433      2008-01-14       1200309300
# 6      DA0001129     PR0000411     FA0002433      2008-10-07       1223381400
# 7      DA0001130     PR0000411     FA0002433      2009-08-25       1251199500
# 8      DA0001131     PR0000411     FA0002433      2010-03-30       1269948600
# 9      DA0001132     PR0000411     FA0002433      2010-04-13       1271157300
# 10     DA0001133     PR0000411     FA0002433      2011-03-10       1299753600
# ...

# %%
ins.head()
# Out:
#   serial_number permit_number facility_id_x inspection_date  inspection_time  \
# 0     DA0001121     PR0000411     FA0002433      2005-03-25       1111746000
# 1     DA0001122     PR0000411     FA0002433      2005-11-07       1131360000
# 2     DA0001123     PR0000411     FA0002433      2005-11-18       1132314000
# 3     DA0001124     PR0000411     FA0002433      2006-09-25       1159179900
# 4     DA0001125     PR0000411     FA0002433      2007-07-25       1185371400
#
#   employee_id  inspection_type_id  inspection_demerits inspection_grade  \
# 0   EE7000535                 916                  4.0                A
# 1   EE7000664                 916                 40.0                C
# 2   EE7000352                 916                  0.0                A
# 3   EE7000735                 916                 10.0                A
# 4   EE0000001                 916                  3.0                A
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248572 entries, 0 to 248571
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   serial_number         248572 non-null  object
#  1   permit_number         248572 non-null  object
#  2   facility_id_x         248572 non-null  object
#  3   inspection_date       248572 non-null  object
#  4   inspection_time       248572 non-null  int64
#  5   employee_id           248572 non-null  object
#  6   inspection_type_id    248572 non-null  int64
#  7   inspection_demerits   248572 non-null  float64
#  8   inspection_grade      248572 non-null  object
#  9   inspection_grade_new  248572 non-null  object
#  10  inspection_result     248572 non-null  object
#  11  violations            248572 non-null  object
#  12  record_updated        248572 non-null  object
#  13  inspection_type       248572 non-null  object
# ...

# %% [markdown]
# ### What is the distribution of inspection demerits like?

# %%
# histogram of demerits
plt.figure(figsize=(6,4))
x = ins[ins.inspection_demerits.notna()]
plt.xlim(xmin=0, xmax=100)
sns.distplot(x.inspection_demerits, bins=30, kde=False, color='green')

# %% [markdown]
# ### most demerits are between 0 and 16

# %%
ins.columns
# Out:
# Index(['serial_number', 'permit_number', 'facility_id_x', 'inspection_date',
#        'inspection_time', 'employee_id', 'inspection_type_id',
#        'inspection_demerits', 'inspection_grade', 'inspection_grade_new',
#        'inspection_result', 'violations', 'record_updated', 'inspection_type',
#        'PE', 'restaurant_name', 'location_name', 'address', 'longitude',
#        'latitude', 'city_id', 'city_name', 'zip_code', 'nciaa'],
#       dtype='object')

# %% [markdown]
# ### How many unique restaurants have been inspected

# %%
unique = set(ins.restaurant_name)
len(unique)
# Out:
# 22558

# %% [markdown]
# ### 22,562 unique restaurants

# %%
# reading the yelp data
yelp = pd.read_csv(r"C:/Users/abdul/Desktop/yelp_post_subsetting.csv")

# %%
yelp.head(10)
# Out:
#                 review_id                 user_id             business_id  \
# 0  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 1  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 2  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 3  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
# 4  JIC8qNMbcAPAzQMPrtsTJw  fxrQSMhHlBv6eJVRdchG9Q  IMLrj2klosTFvPRLv56cng
# 5  j3vP8537KHvoXNHQIr3haA  Z_HE_KKT7N-WddPTzUQC7A  jScBTQtdAt-8RshaiBEHgw
# 6  f0B9-r14-bLudyu5S7aLhw  SvMGr_Oih7ivtzmnCL-Tmg  ujHiaprwCQ5ewziu0Vi9rw
# 7  u1jQX0KfnG3AHty4ifEpFA  8vIK6ndl8yzIdmSDnGp0tw  OVTZNSkSfbl3gVB9XQIJfw
# 8  bvEdkl-weZGMLLRF9e0-ew  0nTJWagRU8_-KS1x7Zw5Yw  X5uxdU9GHoUAqo2wmbg3OQ
# 9  VqZMgUf4wQMTeCWg2M_e8Q  POr1NTWV45OaNCOLfb47fw  OVTZNSkSfbl3gVB9XQIJfw
#
#    stars  useful  funny  cool  \
# 0    4.0       0      0     0
# 1    5.0       0      0     0
# 2    5.0       0      0     0
# ...

# %%
yelp.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_b', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# ### How many unique restaurants do we have reviews for?

# %%
unique = set(yelp.business_id)
len(unique)
# Out:
# 5989

# %% [markdown]
# ### What does the average stars for restaurants in different cities look like

# %%
yelp.groupby('city').stars_b.mean()
# Out:
# city
# Henderson          3.758105
# Las Vegas          3.790714
# North Las Vegas    3.569224
# Name: stars_b, dtype: float64

# %% [markdown]
# ### What is the max date of review data?

# %%
yelp.date.max()
# Out:
# '2018-11-14 18:12:40'

# %% [markdown]
# ### What is the max date of Inspection?

# %%
ins.inspection_date.max()
# Out:
# '2020-01-30'
