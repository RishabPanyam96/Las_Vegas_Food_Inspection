# %%
import pandas as pd

# %%
# Uncomment to read data
yelp = pd.read_csv(r"C:/Users/abdul/Desktop/yelp_combination_done.csv")

# %%
yelp.shape
# Out:
# (2301632, 22)

# %%
# example of categories info
yelp.iloc[14].categories
# Out:
# 'Ethnic Food, American (New), Burgers, Food, Restaurants, Asian Fusion, Specialty Food, Mexican, Sandwiches, Breakfast & Brunch, Korean'

# %%
# checking for NAs
nulls = yelp[yelp.categories.isna()]

# %%
'''
We have 426 cases of NAs for "attributes, categories, and hours" columns
'''
# Out:
# '\nWe have 426 cases of NAs for "attributes, categories, and hours" columns\n'

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 100)

# %%
yelp.head(10)
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
# 2  RS_GTIT6836bCaPy637kNQ  nMeCE5-xsdleyxYuNZ_7rA  oxwGyA17NL6c5t1Etg5WgQ
# 3  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 4  qlXw1JQ0UodW7qrmVgwCXw  bAhqAPoWaZYcyYi7bs024Q  LUN6swQYa4xJKaM_UEUOEw
# 5  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 6  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 7  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 8  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
# 9  DAC4zWY2ZMa1vxpN9RrDvA  yxyRt-zoh_A6PMThX-h9Vw  SNL64axQhCO6Z7ohcWg3wA
#
#    stars  useful  funny  cool  \
# 0    1.0       6      1     0
# 1    5.0       0      0     0
# 2    3.0       1      0     1
# ...

# %% [markdown]
# #### Taking advantage of the 'categories' column to subset for restaurants as a first step

# %%
x = yelp[yelp.categories.notna()]
y = x[x.categories.str.contains('Restaurant' or 'food' or 'bar')]

# %%
yelp = pd.concat([y, nulls], axis=0)
yelp.shape
# Out:
# (1381425, 22)

# %%
yelp = yelp.reset_index(drop=True)

# %%
yelp.head(50)
# Out:
#                  review_id                 user_id             business_id  \
# 0   kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 1   IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 2   S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 3   D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 4   qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
# 5   0AsmPiAQduxh5jE_si8cLA  C_hUvw2z0R-Rv0yZb6QCZA  dm6sO_Y8JdKTE1ZM955yug
# 6   wOv7JiO0EGcJ61P2JcDS1g  en0xQXlvRk-ZtKlaW4I8eQ  N0apJkxIem2E8irTBRKnHw
# 7   JIC8qNMbcAPAzQMPrtsTJw  fxrQSMhHlBv6eJVRdchG9Q  IMLrj2klosTFvPRLv56cng
# 8   j3vP8537KHvoXNHQIr3haA  Z_HE_KKT7N-WddPTzUQC7A  jScBTQtdAt-8RshaiBEHgw
# 9   f0B9-r14-bLudyu5S7aLhw  SvMGr_Oih7ivtzmnCL-Tmg  ujHiaprwCQ5ewziu0Vi9rw
# 10  u1jQX0KfnG3AHty4ifEpFA  8vIK6ndl8yzIdmSDnGp0tw  OVTZNSkSfbl3gVB9XQIJfw
# ...

# %%
yelp.iloc[17, 7]
# Out:
# 'Met an old close friend for dinner at Portofino.  Great intimate dinning with class. Excellent pasta and meat dishes. Delightful service and great drinks. Will come back!'
