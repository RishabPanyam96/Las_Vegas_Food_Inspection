# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)

# %%
# Read the datasets
yelp = pd.read_csv("C:/Users/abdul/Desktop/yelp_post_subsetting.csv")
inspect = pd.read_csv("C:/Users/abdul/Desktop/Inspections_combination_done.csv")

# %%
yelp.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 1  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 2  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 3  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 4  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
#
#    stars  useful  funny  cool  \
# 0    4.0       0      0     0
# 1    4.0       0      0     0
# 2    5.0       0      0     0
# 3    5.0       0      0     0
# 4    5.0       0      0     1
#
#                                                 text                 date  \
# 0  Like walking back in time, every Saturday morn...  2011-11-30 02:11:15
# 1  The food is always good and the prices are rea...  2016-01-17 05:26:22
# 2  Pick any meat on the planet and the chef will ...  2016-07-25 03:57:19
# ...

# %%
yelp['lat_long'] = yelp.latitude.astype(str) + yelp.longitude.astype(str)
yelp.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 1  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 2  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 3  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 4  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
#
#    stars  useful  funny  cool  \
# 0    4.0       0      0     0
# 1    4.0       0      0     0
# 2    5.0       0      0     0
# 3    5.0       0      0     0
# 4    5.0       0      0     1
#
#                                                 text                 date  \
# 0  Like walking back in time, every Saturday morn...  2011-11-30 02:11:15
# 1  The food is always good and the prices are rea...  2016-01-17 05:26:22
# 2  Pick any meat on the planet and the chef will ...  2016-07-25 03:57:19
# ...

# %%
# From this result, it means one lat-long can have multiple restaurants
yelp.groupby(['lat_long', 'name'])['name'].count().head(20)
# Out:
# lat_long                              name
# 35.9208835-115.1652008                Holy Macro                      4
#                                       Mr. Cooker                     54
# 35.9413282617-115.1182061434          Giuseppe's Bar & Grille        12
# 35.9413734745-115.1182101527          Rounders Anthem                79
# 35.941517-115.1183                    Olivo Bistro                   33
# 35.94165507960001-115.11658741049999  Roberto's Taco Shop            66
# 35.9417107701-115.1156285405          New Day Cafe                   60
# 35.9418403858-115.1166500818          Subway                         16
# 35.94247470000001-115.11714909999999  1888 BBQ                        3
#                                       Albertson's                    11
#                                       Haggen Food & Pharmacy         19
# 35.9428967-115.11581480000001         David Clawson Restaurant      118
# ...

# %%
yelp.head(20)
# Out:
#                  review_id                 user_id             business_id  \
# 0   kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 1   IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 2   S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 3   D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 4   qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
# 5   0AsmPiAQduxh5jE_si8cLA  C_hUvw2z0R-Rv0yZb6QCZA  dm6sO_Y8JdKTE1ZM955yug
# 6   wOv7JiO0EGcJ61P2JcDS1g  en0xQXlvRk-ZtKlaW4I8eQ  N0apJkxIem2E8irTBRKnHw
# 7   JIC8qNMbcAPAzQMPrtsTJw  fxrQSMhHlBv6eJVRdchG9Q  IMLrj2klosTFvPRLv56cng
# 8   j3vP8537KHvoXNHQIr3haA  Z_HE_KKT7N-WddPTzUQC7A  jScBTQtdAt-8RshaiBEHgw
# 9   f0B9-r14-bLudyu5S7aLhw  SvMGr_Oih7ivtzmnCL-Tmg  ujHiaprwCQ5ewziu0Vi9rw
# 10  u1jQX0KfnG3AHty4ifEpFA  8vIK6ndl8yzIdmSDnGp0tw  OVTZNSkSfbl3gVB9XQIJfw
# ...

# %%
inspect.head()
# Out:
#   serial_number permit_number facility_id_x inspection_date  inspection_time  \
# 0     DA0001121     PR0000411     FA0002433      2005-03-25       1111746000
# 1     DA0001122     PR0000411     FA0002433      2005-11-07       1131360000
# 2     DA0001123     PR0000411     FA0002433      2005-11-18       1132314000
# 3     DA0001124     PR0000411     FA0002433      2006-09-25       1159179900
# 4     DA0001125     PR0000411     FA0002433      2007-07-25       1185371400
#
#   employee_id  inspection_type_id  inspection_demerits inspection_grade  \
# 0   EE7000535                 916                  4.0                A
# 1   EE7000664                 916                 40.0                C
# 2   EE7000352                 916                  0.0                A
# 3   EE7000735                 916                 10.0                A
# 4   EE0000001                 916                  3.0                A
#
# ...

# %%
sorted(list(inspect.restaurant_name.unique()))
# Out:
# ['#1 HAWAIIAN BARBEQUE',
#  '#1 Hawaiian Barbecue',
#  '$5 CAFE',
#  "'Q ON WHEELS MOBILE BBQ AIHR",
#  '1-800 FLOWERS FRENCH BOUQUET',
#  '100 Academy of Excellence Kitchen',
#  '100 DEGREES C, HOT POT & RAMEN',
#  '100 DEGREES HOT POT - DELETED 10/15',
#  '100 FIRES',
#  '101 MART SNACK BAR',
#  '168 Market - Bakery',
#  '168 Market - Restaurant',
#  '168 Market / Produce Department',
#  '17 SOUTH BOOZE & BITES BAR',
#  '17 SOUTH BOOZE & BITES GRILL',
#  '172 - BAR',
#  '172 - RESTAURANT',
#  '1864 WINE & SPIRITS - GROCERY SAMPLING',
#  '18BIN',
#  '18BIN BAR',
#  '1900 ASIAN CUISINE',
#  '1923 BOURBON BAR',
#  '1923 BOURBON ISLAND BAR/SUPPORT',
#  '1923 BOURBON STAGE BAR',
#  '2 AMIGOS TACOS MOBILE - DELETED',
#  '2 AMIGOS TACOS PORTABLE UNIT',
#  '2 KIDS CATERING',
#  '2 KIDS CATERING - DORAL ACADEMY',
#  '2 KIDS CATERING @ DORAL ACADEMY',
#  '2 MEAT 2 CHESE',
#  '2 SCOOPS OF ALOHA RESTAURANT',
#  '2 YAMA - RESTAURANT',
#  '2 YAMA - SUSHI BAR',
#  '21 Buffet - Buffet',
# ...

# %%
sorted(list(yelp.name.unique()))
# Out:
# ['#1 Hawaiian Barbecue',
#  '1 Hawaiian Barbecue',
#  '100 Degree Hot Pot, Ramen And Boba',
#  '100% Natural Mexican Grill',
#  '100℃',
#  '16 A Handcrafted Experience',
#  '17 South Booze & Bites',
#  '188 Restaurant',
#  '1888 BBQ',
#  '1900 Asian Cuisine',
#  '1923 Bourbon Bar',
#  '2 Scoops of Aloha LV',
#  '2010 Fusion Restaurant',
#  '21 Buffet',
#  '21 Restaurant & Lounge',
#  '221 Wine Bar',
#  '24 Hour Soul Food Express',
#  '24 Seven Cafe',
#  '28GO The Restaurant',
#  '2nd Annual Asian Food Festival',
#  '3 Brothers from Italy Jersey Shore Pizza',
#  '3 Tomatoes & A Mozzarella',
#  '3 Tomatoes and A Mozzarella',
#  '35 Steaks + Martinis',
#  '360 Gourmet Burrito',
#  '3pm Cafe',
#  '420 Baking Companies',
#  '48th and Crepe',
#  '5 Dollar Cafe',
#  '50 Shades Of Green',
#  "50's Diner",
#  "50's Diner Omelet House",
#  '5280 Mexican Grub',
#  '595 Craft And Kitchen',
#  '6500 Tavern',
#  '7-Eleven',
#  '702 Karaoke',
#  '702 Wing Spot',
#  '7th & Carson',
# ...
