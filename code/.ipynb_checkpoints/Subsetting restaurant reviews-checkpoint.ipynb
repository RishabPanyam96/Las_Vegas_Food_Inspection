# %%
import pandas as pd

# %%
# Uncomment to read data
# yelp = pd.read_csv(r"C:/Users/abdul/Desktop/yelp_combination_done.csv")

# %%
yelp.shape
# Out:
# (2301632, 22)

# %%
# example of categories info
yelp.iloc[14].categories
# Out:
# 'Ethnic Food, American (New), Burgers, Food, Restaurants, Asian Fusion, Specialty Food, Mexican, Sandwiches, Breakfast & Brunch, Korean'

# %%
# checking for NAs
yelp[yelp.categories.isna()]
# Out:
#                       review_id                 user_id  \
# 10176    FWe4b_kmPFzOy8FYYzBo8A  fsYWDrNkdJXxSkusduChkw
# 19936    ckGJbN_YhteTIq7l6gwVHA  42GGZfpVhqAvFaRTjCtBgg
# 33943    gAMv7w1CnGIgtBM02tza1A  L5KwCwV8g_tH32MKgLBeiw
# 37225    SjSKXWOAI39a6aoauYLwHA  volBwG3beDUJaLhEhzAy3Q
# 37756    jwX4UHe_goEjjy-OX0XvsA  HWexWirGMojmnD7cRtB4PQ
# ...                         ...                     ...
# 2284471  kegH4nZQGLm7bcoF250ZMA  maHVwTi0PPlCezrirfYzBA
# 2287868  55Wr4lb8G4ge-JLPKcStZQ  B_o8fqE2gmrWLgI022TaaQ
# 2288188  NZ2ecH0QzI8gdP8B2meDOw  BDFMd3ab9kTHhInPkqv6cQ
# 2291229  XppCFN7AzwyiXNqn-vpvjg  Y8VnT8iSNns27YzPVlMRSA
# 2296851  hYlZA8qSJKj_g7JfWNwG7g  OmQG1GhtToR92GYx_GULdQ
#
#                     business_id  stars  useful  funny  cool  \
# 10176    CFWoroWZPq7p3pnjxZWpug    1.0       2      1     0
# 19936    Pjmnta--nDOS6jHCDhsLGg    1.0       0      0     0
# 33943    ZDOW_bRF6wtCNwkakMF-lA    5.0       0      0     0
# 37225    _4423aHxT7EQ3peGS-7uVg    5.0       0      0     0
# 37756    ThEUWXkgLbi5RiulgybrTA    1.0       1      0     0
# ...                         ...    ...     ...    ...   ...
# 2284471  7BIH7ga7YotCM_Bh6qplIA    4.0       1      0     0
# 2287868  uPo3vL_fOIV6QYn-650BGQ    1.0       1      0     0
# 2288188  uPo3vL_fOIV6QYn-650BGQ    1.0       0      0     0
# 2291229  7BIH7ga7YotCM_Bh6qplIA    1.0       1      1     0
# 2296851  t_VsrUZjQp-d7f-ix-0SeQ    1.0       3      0     0
#
#                                                       text  \
# 10176    These people are fucking stupid! You call 4 ti...
# 19936    DO NOT USE THIS LADY !!  RUN-RUN-RUN as fast a...
# 33943    Fantastic Work,   Mr. Noriega is a pleasure to...
# 37225    Switched from Chase. They offer online appoint...
# 37756    This company lost my return package and is bla...
# ...                                                    ...
# 2284471  This review is for the lady at ticket counter....
# 2287868  Miserable place. The HOA is absolutely disgust...
# 2288188  I would rather give this place no stars. We li...
# 2291229  Worst bus to take if you going anywhere I'm su...
# 2296851  This company is a joke, Clint the granite GM a...
#
#                         date                      name  ... state postal_code  \
# 10176    2017-01-15 16:36:41             Nevada Energy  ...    NV     89015.0
# 19936    2016-07-04 17:33:20           Realtech Realty  ...    NV     89032.0
# 33943    2018-05-10 20:38:13           Noriega Masonry  ...    NV     89129.0
# 37225    2018-01-01 03:26:16           Bank of America  ...    NV     89121.0
# 37756    2017-10-13 16:46:56    Monster Cable Products  ...    NV     89030.0
# ...                      ...                       ...  ...   ...         ...
# 2284471  2017-10-19 20:12:10  Los Paisanos Bus Company  ...    NV     89101.0
# 2287868  2018-03-03 21:28:29                  Tera Hoa  ...    NV     89122.0
# 2288188  2018-08-06 20:15:12                  Tera Hoa  ...    NV     89122.0
# 2291229  2014-09-29 01:02:54  Los Paisanos Bus Company  ...    NV     89101.0
# 2296851  2016-06-11 02:16:53      Interior Specialists  ...    NV     89113.0
#
#           latitude   longitude  stars_b  review_count  is_open  attributes  \
# 10176    36.031280 -114.982555      1.0             8        1         NaN
# 19936    36.222009 -115.173879      1.0             3        1         NaN
# 33943    36.230764 -115.281976      3.5             3        1         NaN
# 37225    36.115763 -115.094714      1.5             8        1         NaN
# 37756    36.228780 -115.105535      1.0             3        1         NaN
# ...            ...         ...      ...           ...      ...         ...
# 2284471  36.159718 -115.118993      2.5             5        1         NaN
# 2287868  36.093365 -115.048128      1.0             3        1         NaN
# 2288188  36.093365 -115.048128      1.0             3        1         NaN
# 2291229  36.159718 -115.118993      2.5             5        1         NaN
# 2296851  36.069724 -115.253655      1.5             8        1         NaN
#
#          categories hours
# 10176           NaN   NaN
# 19936           NaN   NaN
# 33943           NaN   NaN
# 37225           NaN   NaN
# 37756           NaN   NaN
# ...             ...   ...
# 2284471         NaN   NaN
# 2287868         NaN   NaN
# 2288188         NaN   NaN
# 2291229         NaN   NaN
# 2296851         NaN   NaN
#
# [426 rows x 22 columns]

# %%
'''
We have 426 cases of NAs for "attributes, categories, and hours" columns
'''
# Out:
# '\nWe have 426 cases of NAs for "attributes, categories, and hours" columns\n'

# %%
yelp.head(10)
# Out:
#                 review_id                 user_id             business_id  \
# 0  Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA  ujmEBvifdJM6h6RLv4wQIg
# 1  GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg  NZnhc2sEQy3RmzKTZnqtwQ
# 2  RS_GTIT6836bCaPy637kNQ  nMeCE5-xsdleyxYuNZ_7rA  oxwGyA17NL6c5t1Etg5WgQ
# 3  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 4  qlXw1JQ0UodW7qrmVgwCXw  bAhqAPoWaZYcyYi7bs024Q  LUN6swQYa4xJKaM_UEUOEw
# 5  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 6  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 7  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 8  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
# 9  DAC4zWY2ZMa1vxpN9RrDvA  yxyRt-zoh_A6PMThX-h9Vw  SNL64axQhCO6Z7ohcWg3wA
#
#    stars  useful  funny  cool  \
# 0    1.0       6      1     0
# 1    5.0       0      0     0
# 2    3.0       1      0     1
# 3    4.0       0      0     0
# 4    4.0       0      0     0
# 5    4.0       0      0     0
# 6    5.0       0      0     0
# 7    5.0       0      0     0
# 8    5.0       0      0     1
# 9    1.0       0      0     0
#
#                                                 text                 date  \
# 0  Total bill for this horrible service? Over $8G...  2013-05-07 04:34:36
# 1  I *adore* Travis at the Hard Rock's new Kelly ...  2017-01-14 21:30:33
# 2  It's a giant Best Buy with 66 registers.  I do...  2012-02-29 21:52:43
# 3  Like walking back in time, every Saturday morn...  2011-11-30 02:11:15
# 4  Michael from Red Carpet VIP is amazing ! I rea...  2018-04-27 20:25:26
# 5  The food is always good and the prices are rea...  2016-01-17 05:26:22
# 6  Pick any meat on the planet and the chef will ...  2016-07-25 03:57:19
# 7  Great food, great service. Obviously fried chi...  2012-11-06 03:41:43
# 8  their pettuccine was fresh-made in the morning...  2013-12-28 22:28:08
# 9  This review is in regards to our experience wa...  2017-02-09 03:43:25
#
#                                               name  ... state postal_code  \
# 0                            MountainView Hospital  ...    NV     89128.0
# 1  Kelly Cardenas Salon - Hard Rock Hotel & Casino  ...    NV     89169.0
# 2                                            Fry's  ...    NV     89119.0
# 3                             Pinball Hall Of Fame  ...    NV     89119.0
# 4                                   Red Carpet VIP  ...    NV     89109.0
# 5                                 Greenberg's Deli  ...    NV     89136.0
# 6                                     Border Grill  ...    NV     89119.0
# 7                                     Chicken Bonz  ...    NV     89118.0
# 8                                         Casanova  ...    NV     89109.0
# 9                               Westgate Sportbook  ...    NV     89109.0
#
#     latitude   longitude  stars_b  review_count  is_open  \
# 0  36.215546 -115.248798      2.5           238        1
# 1  36.110083 -115.153871      4.5            66        1
# 2  36.065085 -115.174592      2.5           515        1
# 3  36.101449 -115.130511      4.5          1258        1
# 4  36.131931 -115.160451      4.5           153        1
# 5  36.102379 -115.174547      4.0           333        1
# 6  36.090067 -115.176973      4.0          1623        1
# 7  36.071196 -115.207463      3.0            52        0
# 8  36.121579 -115.168664      4.0           495        1
# 9  36.136097 -115.151489      3.5            80        1
#
#                                           attributes  \
# 0  {'ByAppointmentOnly': 'False', 'GoodForKids': ...
# 1  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 2  {'WheelchairAccessible': 'True', 'RestaurantsP...
# 3  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 4  {'HasTV': 'False', 'RestaurantsPriceRange2': '...
# 5  {'RestaurantsPriceRange2': '2', 'HasTV': 'Fals...
# 6  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'Tru...
# 7  {'Ambience': "{'romantic': False, 'intimate': ...
# 8  {'HasTV': 'True', 'Ambience': "{'romantic': Fa...
# 9                           {'GoodForKids': 'False'}
#
#                                           categories  \
# 0  Fitness & Instruction, Doctors, Health & Medic...
# 1  Beauty & Spas, Hair Stylists, Makeup Artists, ...
# 2    Shopping, Computers, Electronics, Mobile Phones
# 3  Performing Arts, Amusement Parks, Museums, Arc...
# 4  Hotels & Travel, Travel Services, Nightlife, T...
# 5              Delis, Sandwiches, Pizza, Restaurants
# 6  Breakfast & Brunch, Restaurants, Tapas/Small P...
# 7                Chicken Wings, Burgers, Restaurants
# 8    Restaurants, Tapas Bars, Mediterranean, Italian
# 9                      Casinos, Arts & Entertainment
#
#                                                hours
# 0  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 1  {'Monday': '10:0-17:0', 'Tuesday': '10:0-19:0'...
# 2  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 3  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 4  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...
# 5  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 6  {'Monday': '10:0-22:0', 'Tuesday': '11:0-22:0'...
# 7  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 8  {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
# 9  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
#
# [10 rows x 22 columns]
