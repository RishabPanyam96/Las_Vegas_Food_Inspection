# %%
import pandas as pd
import numpy as np
import json

# %%
from nltk import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
#import googlemaps
#gmaps = googlemaps.Client(key =Your_key)
#key_map = Your_key

# %%
from difflib import SequenceMatcher

# %%
# pip install --upgrade pip

# %%
#python3 pylcs.py sdist
#python3 pylcs.py bdist_wheel

# %%
#export PYTHONPATH = 'c:\users\13129\appdata\local\continuum\anaconda3\lib\site-packages'

# %%
import warnings
warnings.simplefilter('ignore')

# %%
# pip install distance-metrics

# %%
import distance_metrics

# %%
from distance_metrics import lcs

# %%
import re

# %%
pip install editdistance
# Out:
# Requirement already satisfied: editdistance in c:\users\abdul\anaconda3\lib\site-packages (0.5.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import editdistance
import nltk

# %%
# initalizing links for our files
business_data_google = 'D:/down/business_df.csv'
business_data_url = 'D:/down/yelpdataset/business.json'
inspection_data_url = 'D:/down/restaurants/restaurant_inspections.csv'
inspection_rest_url = 'D:/down/restaurants/restaurant_establishments.csv'
review_data_url = 'D:/down/yelpdataset/review.json'

# %%
business_df = pd.read_json(r"C:\Users\abdul\desktop\yelp\business.json", lines=True)

# %%
def get_levinshtein_distance_city(df, city_name, city_column_name):
    df['city_'] = df[city_column_name].apply(lambda x: x.lower().strip().title())
    column_name = city_name[:1] + '_levi_dist'
    df[column_name] = df.loc[:, 'city_'].apply(lambda x: editdistance.eval(x, city_name))

# %%
def clean_city_name(df, replace_with, city_column_name, cutoff):
    column_name = replace_with[:1] + '_levi_dist'
    df.loc[df[column_name] < cutoff, city_column_name] = replace_with

# %%
business_df.drop(business_df.columns[-1], axis = 1, inplace = True)

# %%
get_levinshtein_distance_city(business_df, 'North Las Vegas', 'city')

# %%
business_df = business_df[business_df['city_'] != 'South Las Vegas']

# %%
business_df[(business_df['N_levi_dist'] < 5) & (business_df['N_levi_dist'] > 0)]
# Out:
#                    business_id                                        name  \
# 12686   m09U1hgWg94Z-9iyVuOkYA               Nevada Orthotics & Prosthetic
# 17423   zBlh5vP_qkSNR5Cc6lWG4w                        Little Caesars Pizza
# 23849   f1uziLh9BeWsm5SBUmsPqg                             The Tech Monkey
# 29864   l8WJ-Imy2FqHuZ1T2utTcw                                JDS Surfaces
# 30998   Y7T9osP-hoqp2nLnmIi12w                          Buffalo Wild Wings
# 39306   zdxKXLJR1obxtkSGlwaThw                  Blue Brothers Pool Service
# 48752   ldbgYzpbXMZ3MD7PYoZLWA                       Infinity Custom Glass
# 55829   vQU7ed_nxfY94MLhs5ii_Q                          Dollar Loan Center
# 69308   EcHm_jsbFJMnBmRr_ji8Vw  Mike Whitford - State Farm Insurance Agent
# 71027   ttsLdrsKe24vXZcmZXcZ4g                             Jack in the Box
# 78405   Ua1fGA87fa5xhnitZwoV5g                     Lowe's Home Improvement
# 81607   bB9RVbFrixBg_-CldjFk5g                                  Water Pros
# 91435   ES9SowkyQSvVG-5LNTK-1A                              Ec Water Store
# 91500   O-nd3gw4A13i1pdKpr_Gkg                       Sierra Moving Systems
# 156493  36.239386 -115.112484    3.5             3        1
# 157954  36.198360 -115.192997    2.5             7        1
# 163804  36.262525 -115.206694    4.0            10        1
# 165255  36.238192 -115.164345    3.5             3        0
# 168007  36.241157 -115.226894    2.5            74        1
# 170354  36.221502 -115.128768    3.5             8        1
# 172475  36.286925 -115.132864    3.5            23        1
# 178023  36.196622 -115.184772    2.5             3        1
# 180746  36.253939 -115.156658    4.5             6        1
# 186720  36.261583 -115.189938    4.5            12        0
#
#                                                attributes  \
# 12686                                                None
# 17423   {'RestaurantsGoodForGroups': 'False', 'WiFi': ...
# 23849   {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 29864   {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 30998   {'Caters': 'True', 'Music': '{'dj': False, 'ba...
# 39306                                                None
# 48752   {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 55829                                                None
# 69308                                                None
# 71027   {'BusinessParking': '{'garage': False, 'street...
# 78405   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 81607             {'BusinessAcceptsCreditCards': 'False'}
# 91435   {'BusinessParking': '{'garage': False, 'street...
# 91500              {'BusinessAcceptsCreditCards': 'True'}
# 109536  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 116290  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 117619  {'BusinessParking': '{'garage': False, 'street...
# 118288  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 120414  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 121673  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 132494                                               None
# 132534  {'RestaurantsReservations': 'False', 'Restaura...
# 133828  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 133980             {'BusinessAcceptsCreditCards': 'True'}
# 134901  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 139277  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 143069  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 152015  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 153190  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 155664  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 156493                                               None
# 157954  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 163804             {'BusinessAcceptsCreditCards': 'True'}
# 165255  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 168007  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 170354  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 172475  {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 178023                                               None
# 180746                                               None
# 186720                            {'GoodForKids': 'True'}
#
#                                                categories          city_  \
# 12686   Orthotics, Laser Eye Surgery/Lasik, Health & M...   N. Las Vegas
# 17423                       Restaurants, Fast Food, Pizza   N. Las Vegas
# 23849   Home Network Installation, IT Services & Compu...    N Las Vegas
# 29864   Home & Garden, Shopping, Kitchen & Bath, Build...   N. Las Vegas
# 30998   Sports Bars, Bars, Restaurants, Nightlife, Ame...   N. Las Vegas
# 39306                        Home Services, Pool Cleaners    N Las Vegas
# 48752                      Home Services, Glass & Mirrors    N Las Vegas
# 55829     Financial Services, Check Cashing/Pay-day Loans   N. Las Vegas
# 69308   Financial Services, Auto Insurance, Home & Ren...    N Las Vegas
# 71027                                Burgers, Restaurants    N Las Vegas
# 78405   Hardware Stores, Home Services, Shopping, Home...  N E Las Vegas
# 81607   Water Delivery, Party & Event Planning, Local ...    N Las Vegas
# 91435   Food, Water Delivery, Local Services, Health M...    N Las Vegas
# 91500                               Home Services, Movers    N Las Vegas
# 109536  Local Services, Contractors, Awnings, Shades &...   N. Las Vegas
# 116290                    Restaurants, Fast Food, Chinese    N Las Vegas
# 117619                            Mobile Phones, Shopping   N. Las Vegas
# 118288               Contractors, Plumbing, Home Services    N Las Vegas
# 120414  Home Services, Pool & Hot Tub Service, Tree Se...    N Las Vegas
# 121673                         Nail Salons, Beauty & Spas    N Las Vegas
# 132494  Pet Services, Pets, Pet Stores, Pet Groomers, ...    N Las Vegas
# 132534                               Restaurants, Burgers    N Las Vegas
# 133828        Dance Clubs, Adult Entertainment, Nightlife    N Las Vegas
# 133980            Towing, Automotive, Roadside Assistance    N Las Vegas
# 134901                           Discount Store, Shopping    N Las Vegas
# 139277  Pool & Hot Tub Service, Professional Services,...    N Las Vegas
# 143069                    Fast Food, Restaurants, Mexican    N Las Vegas
# 152015  Professional Services, Business Consulting, Ar...   N. Las Vegas
# 153190                               Restaurants, Mexican    N Las Vegas
# 155664  Home Services, Self Storage, Movers, Local Ser...   N. Las Vegas
# 156493  Professional Services, Signmaking, Local Servi...   N. Las Vegas
# 157954                               Restaurants, Burgers    N Las Vegas
# 163804  Mailbox Centers, Graphic Design, Notaries, Loc...    N Las Vegas
# 165255  Shopping, Electronics, Hobby Shops, Mobile Phones    N Las Vegas
# 168007  Hardware Stores, Shopping, Building Supplies, ...  N W Las Vegas
# 170354  Gardeners, Home Services, Tree Services, Lands...   N. Las Vegas
# 172475  Flowers & Gifts, Cards & Stationery, Event Pla...    N Las Vegas
# 178023                            Automotive, Auto Repair    N Las Vegas
# 180746  First Aid Classes, Specialty Schools, Educatio...   N. Las Vegas
# 186720  Trainers, Fitness & Instruction, Boot Camps, G...    N Las Vegas
#
#         N_levi_dist
# 12686             4
# 17423             4
# 23849             4
# 29864             4
# 30998             4
# 39306             4
# 48752             4
# 55829             4
# 69308             4
# 71027             4
# 78405             4
# 81607             4
# 91435             4
# 91500             4
# 109536            4
# 116290            4
# 117619            4
# 118288            4
# 120414            4
# 121673            4
# 132494            4
# 132534            4
# 133828            4
# 133980            4
# 134901            4
# 139277            4
# 143069            4
# 152015            4
# 153190            4
# 155664            4
# 156493            4
# 157954            4
# 163804            4
# 165255            4
# 168007            4
# 170354            4
# 172475            4
# 178023            4
# 180746            4
# 186720            4

# %%
get_levinshtein_distance_city(business_df, 'Las Vegas', 'city')

# %%
clean_city_name(business_df, 'North Las Vegas', 'city', 5)

# %%
business_df[(business_df['L_levi_dist'] < 5) & (business_df['L_levi_dist'] > 0)]
# Out:
#                    business_id  \
# 3993    d20nYbRK7_TRRofOpzRZNQ
# 12686   m09U1hgWg94Z-9iyVuOkYA
# 17423   zBlh5vP_qkSNR5Cc6lWG4w
# 23849   f1uziLh9BeWsm5SBUmsPqg
# 28686   QVFfbOZBtIEH0VretoMXLQ
# 29864   l8WJ-Imy2FqHuZ1T2utTcw
# 30998   Y7T9osP-hoqp2nLnmIi12w
# 39306   zdxKXLJR1obxtkSGlwaThw
# 47208   t8xvlKk5axVYy2c2p70NRg
# 48752   ldbgYzpbXMZ3MD7PYoZLWA
# 49456   6E5SM3-YvBpdzNNW68ksTw
# 55829   vQU7ed_nxfY94MLhs5ii_Q
'RestaurantsPriceRange2': '2', 'BusinessParki...
# 78405   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 81607             {'BusinessAcceptsCreditCards': 'False'}
# 85872   {'BusinessParking': '{'garage': True, 'street'...
# 88219   {'RestaurantsPriceRange2': '3', 'BusinessParki...
# 89357              {'BusinessAcceptsCreditCards': 'True'}
# 89945   {'DriveThru': 'False', 'Ambience': '{'romantic...
# 91435   {'BusinessParking': '{'garage': False, 'street...
# 91500              {'BusinessAcceptsCreditCards': 'True'}
# 98671   {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 105458  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 109536  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 116290  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 117619  {'BusinessParking': '{'garage': False, 'street...
# 118288  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 120414  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 121673  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 132494                                               None
# 132534  {'RestaurantsReservations': 'False', 'Restaura...
# 133828  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 133980             {'BusinessAcceptsCreditCards': 'True'}
# 134901  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 139277  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 142829             {'BusinessAcceptsCreditCards': 'True'}
# 143069  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 151045                           {'GoodForKids': 'False'}
# 152015  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 153190  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 155664  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 156493                                               None
# 157954  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 161165                                               None
# 163804             {'BusinessAcceptsCreditCards': 'True'}
# 165255  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 168007  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 169862  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 170354  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 172475  {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 178023                                               None
# 179012  {'BusinessAcceptsCreditCards': 'True', 'CoatCh...
# 180746                                               None
# 186720                            {'GoodForKids': 'True'}
# 188956                                               None
#
#                                                categories          city_  \
# 3993    Home Services, Plumbing, Water Purification Se...       La Vegas
# 12686   Orthotics, Laser Eye Surgery/Lasik, Health & M...   N. Las Vegas
# 17423                       Restaurants, Fast Food, Pizza   N. Las Vegas
# 23849   Home Network Installation, IT Services & Compu...    N Las Vegas
# 28686        Dog Walkers, Pet Services, Pets, Pet Sitting     Las Vegass
# 29864   Home & Garden, Shopping, Kitchen & Bath, Build...   N. Las Vegas
# 30998   Sports Bars, Bars, Restaurants, Nightlife, Ame...   N. Las Vegas
# 39306                        Home Services, Pool Cleaners    N Las Vegas
# 47208   Hair Extensions, Hair Stylists, Makeup Artists...   Las Vegas Nv
# 48752                      Home Services, Glass & Mirrors    N Las Vegas
# 49456   Real Estate Agents, Real Estate Services, Real...   Las Vegas Nv
# 55829     Financial Services, Check Cashing/Pay-day Loans   N. Las Vegas
# 63321                              Barbers, Beauty & Spas          Vegas
# 65197   Nail Salons, Hair Removal, Beauty & Spas, Skin...  Las Vegas, Nv
# 69308   Financial Services, Auto Insurance, Home & Ren...    N Las Vegas
# 71027                                Burgers, Restaurants    N Las Vegas
# 74494   Sporting Goods, Guns & Ammo, Shopping, Outdoor...     Las Vegas,
# 77692   Shopping, Home & Garden, Building Supplies, Ho...    C Las Vegas
# 78405   Hardware Stores, Home Services, Shopping, Home...  N E Las Vegas
# 81607   Water Delivery, Party & Event Planning, Local ...    N Las Vegas
# 81607             4            2
# 85872             7            1
# 88219            10            4
# 89357             7            1
# 89945             8            2
# 91435             4            2
# 91500             4            2
# 98671             7            1
# 105458            7            1
# 109536            4            3
# 116290            4            2
# 117619            4            3
# 118288            4            2
# 120414            4            2
# 121673            4            2
# 132494            4            2
# 132534            4            2
# 133828            4            2
# 133980            4            2
# 134901            4            2
# 139277            4            2
# 142829            5            4
# 143069            4            2
# 151045            7            1
# 152015            4            3
# 153190            4            2
# 155664            4            3
# 156493            4            3
# 157954            4            2
# 161165            7            1
# 163804            4            2
# 165255            4            2
# 168007            4            4
# 169862            7            1
# 170354            4            3
# 172475            4            2
# 178023            4            2
# 179012            8            2
# 180746            4            3
# 186720            4            2
# 188956            7            1

# %%
clean_city_name(business_df, 'Las Vegas', 'city', 5)

# %%
business_df[(business_df['L_levi_dist'] < 5) & (business_df['L_levi_dist'] > 0)]
# Out:
#                    business_id  \
# 3993    d20nYbRK7_TRRofOpzRZNQ
# 12686   m09U1hgWg94Z-9iyVuOkYA
# 17423   zBlh5vP_qkSNR5Cc6lWG4w
# 23849   f1uziLh9BeWsm5SBUmsPqg
# 28686   QVFfbOZBtIEH0VretoMXLQ
# 29864   l8WJ-Imy2FqHuZ1T2utTcw
# 30998   Y7T9osP-hoqp2nLnmIi12w
# 39306   zdxKXLJR1obxtkSGlwaThw
# 47208   t8xvlKk5axVYy2c2p70NRg
# 48752   ldbgYzpbXMZ3MD7PYoZLWA
# 49456   6E5SM3-YvBpdzNNW68ksTw
# 55829   vQU7ed_nxfY94MLhs5ii_Q
# 63321   sOQBfSKH9EXM6nRgtGaE3w
# 65197   oQraEYPdsFyjs-Q_Dmn4uw
# 69308   EcHm_jsbFJMnBmRr_ji8Vw
# 71027   ttsLdrsKe24vXZcmZXcZ4g
# 74494   axYby0KsY2PsfGv_HzAe9g
# 77692   5DetOjfJ_d3qvAP0WbdOSw
# 78405   Ua1fGA87fa5xhnitZwoV5g
# 81607   bB9RVbFrixBg_-CldjFk5g
# 85872   7RR1rbyEKKo2G-RACqAfoA
# 88219   0mpL21omHLi4mHWs3Ee29g
# 89357   _3HVR6jHVUsXBh6K1BX8Pw
# 89945   fDQF6ojXgCZsqaqQkrQvdQ
# 91435   ES9SowkyQSvVG-5LNTK-1A
# 91500   O-nd3gw4A13i1pdKpr_Gkg
# 98671   Rmiv34SGRqJDm_5Db29IrQ
# 105458  MX2OYa2sS5ys_6AiK-gs3A
# 109536  QFR-ty1CPMCirSnZuZ5ayw
# 116290  j4nX7yJFULEXXjMKBLwDLw
# 117619  WPM5eDqWmCYpRDcG3ihRGg
# 118288  c7-gIO71adWmNjj9tz-ugQ
# 120414  ZXxi3Xu4ZYcdzZ4BrBirBQ
# 121673  zI5hl38DTxXv3RHCJqBmbQ
# 132494  xbdv7He4jVk53sX9deBM3w
# 132534  Jfnb9IDQ326omYqA-buX_w
# 133828  SUgldud8wiwCg5tkULepBQ
# 133980  z3oRicoIlFsja9YnhezHfg
# 134901  k2z2c-opKwIbsTpg-R0BYg
# 152015  36.229929 -115.102632    3.5            13        1
# 153190  36.261223 -115.180169    2.5             3        0
# 155664  36.212938 -115.175951    2.0           177        1
# 156493  36.239386 -115.112484    3.5             3        1
# 157954  36.198360 -115.192997    2.5             7        1
# 161165  36.180082 -115.243102    2.5             3        1
# 163804  36.262525 -115.206694    4.0            10        1
# 165255  36.238192 -115.164345    3.5             3        0
# 168007  36.241157 -115.226894    2.5            74        1
# 169862  36.125545 -115.190506    5.0             4        0
# 170354  36.221502 -115.128768    3.5             8        1
# 172475  36.286925 -115.132864    3.5            23        1
# 178023  36.196622 -115.184772    2.5             3        1
# 179012  36.102379 -115.174547    4.5             5        1
# 180746  36.253939 -115.156658    4.5             6        1
# 186720  36.261583 -115.189938    4.5            12        0
# 188956  36.168471 -115.223582    5.0             3        1
#
#                                                attributes  \
# 3993    {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 12686                                                None
# 17423   {'RestaurantsGoodForGroups': 'False', 'WiFi': ...
# 23849   {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 28686                                                None
# 29864   {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 30998   {'Caters': 'True', 'Music': '{'dj': False, 'ba...
# 39306                                                None
# 47208   {'BikeParking': 'True', 'ByAppointmentOnly': '...
# 48752   {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 49456   {'BusinessAcceptsCreditCards': 'False', 'Busin...
# 55829                                                None
# 63321   {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 65197   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 69308                                                None
# 71027   {'BusinessParking': '{'garage': False, 'street...
# 74494   {'BusinessParking': '{'garage': False, 'street...
# 77692   {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 78405   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 81607             {'BusinessAcceptsCreditCards': 'False'}
# 85872   {'BusinessParking': '{'garage': True, 'street'...
# 88219   {'RestaurantsPriceRange2': '3', 'BusinessParki...
# 89357              {'BusinessAcceptsCreditCards': 'True'}
# 89945   {'DriveThru': 'False', 'Ambience': '{'romantic...
# 91435   {'BusinessParking': '{'garage': False, 'street...
# 91500              {'BusinessAcceptsCreditCards': 'True'}
# 98671   {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 105458  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 109536  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 116290  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 117619  {'BusinessParking': '{'garage': False, 'street...
# 118288  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 120414  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 121673  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 132494                                               None
# 132534  {'RestaurantsReservations': 'False', 'Restaura...
# 133828  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 133980             {'BusinessAcceptsCreditCards': 'True'}
# 134901  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 139277  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 142829             {'BusinessAcceptsCreditCards': 'True'}
# 143069  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 151045                           {'GoodForKids': 'False'}
# 152015  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 153190  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 155664  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 156493                                               None
# 157954  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 161165                                               None
# 163804             {'BusinessAcceptsCreditCards': 'True'}
# 165255  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 168007  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 169862  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 170354  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 172475  {'RestaurantsPriceRange2': '2', 'BikeParking':...
#
# 153190                               Restaurants, Mexican    N Las Vegas
# 155664  Home Services, Self Storage, Movers, Local Ser...   N. Las Vegas
# 156493  Professional Services, Signmaking, Local Servi...   N. Las Vegas
# 157954                               Restaurants, Burgers    N Las Vegas
# 161165  Divorce & Family Law, Lawyers, Health & Medica...     Las  Vegas
# 163804  Mailbox Centers, Graphic Design, Notaries, Loc...    N Las Vegas
# 165255  Shopping, Electronics, Hobby Shops, Mobile Phones    N Las Vegas
# 168007  Hardware Stores, Shopping, Building Supplies, ...  N W Las Vegas
# 169862                    Tattoo, Piercing, Beauty & Spas     Las  Vegas
# 170354  Gardeners, Home Services, Tree Services, Lands...   N. Las Vegas
# 172475  Flowers & Gifts, Cards & Stationery, Event Pla...    N Las Vegas
# 178023                            Automotive, Auto Repair    N Las Vegas
# 179012                           Nightlife, Bars, Lounges       Lasvegas
# 180746  First Aid Classes, Specialty Schools, Educatio...   N. Las Vegas
# 186720  Trainers, Fitness & Instruction, Boot Camps, G...    N Las Vegas
# 188956  Hair Loss Centers, Hair Salons, Beauty & Spas,...     Las Vergas
#
#         N_levi_dist  L_levi_dist
# 3993              7            1
# 12686             4            3
# 17423             4            3
# 23849             4            2
# 28686             7            1
# 29864             4            3
# 30998             4            3
# 39306             4            2
# 47208             9            3
# 48752             4            2
# 49456             9            3
# 55829             4            3
# 63321            10            4
# 65197            10            4
# 69308             4            2
# 71027             4            2
# 74494             7            1
# 77692             5            2
# 78405             4            4
# 81607             4            2
# 85872             7            1
# 88219            10            4
# 89357             7            1
# 89945             8            2
# 91435             4            2
# 91500             4            2
# 98671             7            1
# 105458            7            1
# 109536            4            3
# 116290            4            2
# 117619            4            3
# 118288            4            2
# 120414            4            2
# 121673            4            2
# 132494            4            2
# 132534            4            2
# 133828            4            2
# 133980            4            2
# 134901            4            2
# 139277            4            2
# 142829            5            4
# 143069            4            2
# 151045            7            1
# 152015            4            3
# 153190            4            2
# 155664            4            3
# 156493            4            3
# 157954            4            2
# 161165            7            1
# 163804            4            2
# 165255            4            2
# 168007            4            4
# 169862            7            1
# 170354            4            3
# 172475            4            2
# 178023            4            2
# 179012            8            2
# 180746            4            3
# 186720            4            2
# 188956            7            1

# %%
get_levinshtein_distance_city(business_df, 'Henderson', 'city')

# %%
business_df[(business_df['H_levi_dist'] < 4) & (business_df['H_levi_dist'] > 0)]
# Out:
#                    business_id                                name  \
# 20195   G3VVtNuIZCYndh3OwoGrKQ                Ryan C Shipp, DMD MS
# 49811   M0RU7x_4Tg1ITUQCASFDQw                Tours of Distinction
# 100155  sEIYwtCebPe9QZJfEQ5Pdg             Lowe's Home Improvement
# 179305  UenZP1tN5itN4zUjlu7ztA  Fast Fix Jewelry and Watch Repairs
#
#                                   address         city state postal_code  \
# 20195                     9053 S Pecos Rd   Hendserson    NV       89074
# 49811   1000 N Green Valley Pkwy, Ste 440    Hnederson    NV       89074
# 100155                 9955 S Eastern Ave  W Henderson    NV       89123
# 179305         1300 W Sunset Rd, Ste 1537   Henderston    NV       89014
#
#          latitude   longitude  stars  review_count  is_open  \
# 20195   36.025225 -115.101460    4.5            13        1
# 49811   36.027507 -115.083852    3.5             3        1
# 100155  36.007479 -115.117951    2.5            99        1
# 179305  36.067252 -115.041219    4.0            67        1
#
#                                                attributes  \
# 20195   {'AcceptsInsurance': 'True', 'ByAppointmentOnl...
# 49811                                                None
# 100155  {'BusinessParking': '{'garage': False, 'street...
# 179305  {'BusinessParking': '{'garage': False, 'street...
#
#                                                categories        city_  \
# 20195            Dentists, Health & Medical, Endodontists   Hendserson
# 49811                              Tours, Hotels & Travel    Hnederson
# 100155  Home Services, Grocery, Nurseries & Gardening,...  W Henderson
# 179305  Watch Repair, Shopping, Jewelry Repair, Local ...   Henderston
#
#         N_levi_dist  L_levi_dist  H_levi_dist
# 20195            14            9            1
# 49811            14            9            2
# 100155           14           10            2
# 179305           14           10            1

# %%
clean_city_name(business_df, 'Henderson', 'city', 4)

# %%
business_df = business_df[(business_df['city'] == 'North Las Vegas') | (business_df['city'] == 'Las Vegas') | (business_df['city'] == 'Henderson')]

# %%
business_df.drop(['city_', 'H_levi_dist', 'L_levi_dist', 'N_levi_dist'], axis = True, inplace = True)

# %%
business_df.city.value_counts()
# Out:
# Las Vegas          29476
# Henderson           4907
# North Las Vegas     1550
# Name: city, dtype: int64

# %%
business_df = business_df.reset_index(drop =True)

# %%
food_related = ['Tacos','Custom Cakes', 'Wine & Spirits', 'Sandwiches', 'Hookah Bars', 'Ice Cream & Frozen Yogurt',
                             'Middle Eastern', 'Gastropubs', 'Chicken Wings','Fast Food','Soup','French',
                             'Tex-Mex','Specialty Food','Persian/Iranian','Wine Bars', 'Hot Dogs','Dive Bars', 'Chinese',
                            'Buffets','Barbeque','Beer Gardens', 'Desserts','Cafes','Vietnamese','Burgers','Fish & Chips',
                             'Southern','Pubs', 'Japanese','Vegan','Thai','Imported Food','Pizza','Canadian (New)','Turkish',
                            'Mexican', 'American (Traditional)','Modern European','Bakeries','Bars','Dim Sum','Ethnic Food',
                            'Seafood', 'Delis','Cajun/Creole','Cupcakes','Vegetarian','Diners','Steakhouses','Irish Pub',
                             'Italian','Tapas Bars','American (New)', 'Food Banks','Breakfast & Brunch','Restaurants', 'Donuts',
                             'Juice Bars & Smoothies','Beer','Caterers','Asian Fusion','Salad','Herbs & Spices','Korean',
                             'Food','Mediterranean','Caribbean','Portuguese','Sushi Bars','Coffee & Tea','Comfort Food']

# %%
def food_filter(x):
    if (x == None):
        return False
    for i in food_related:
        if ( i in x):
            return (True)
    return False

# %%
business_df =business_df[business_df.categories.apply(lambda x:food_filter(x))]

# %%
business_df = business_df.reset_index(drop =True)

# %%
# Getting establishments info
establishment_df = pd.read_csv(r"C:/Users/abdul/Desktop/CSP 571/Project/restaurants/restaurant_establishments.csv",
                              delimiter=";")

# %%
establishment_df.drop(establishment_df.columns[-1], axis = 1, inplace = True)

# %%
get_levinshtein_distance_city(establishment_df, 'North Las Vegas', 'city_name')

# %%
establishment_df.loc[(establishment_df['N_levi_dist'] < 5) & (establishment_df['N_levi_dist'] > 0), ['city_id', 'city_name']]
# Out:
#        city_id        city_name
# 25119       -1  North LasV EGAS

# %%
clean_city_name(establishment_df, 'North Las Vegas', 'city_name', 5)

# %%
get_levinshtein_distance_city(establishment_df, 'Las Vegas', 'city_name')

# %%
establishment_df.loc[(establishment_df['L_levi_dist'] < 5) & (establishment_df['L_levi_dist'] > 0), ['city_id', 'city_name']]
# Out:
#        city_id     city_name
# 21087       -1      La VeGAS
# 25590       -1      Las VGAS
# 25820       -1  Las Vegas NV
# 25821       -1  Las Vegas NV

# %%
clean_city_name(establishment_df, 'Las Vegas', 'city_name', 5)

# %%
get_levinshtein_distance_city(establishment_df, 'Henderson', 'city_name')

# %%
establishment_df.loc[(establishment_df['H_levi_dist'] < 5) & (establishment_df['H_levi_dist'] > 0), ['city_id', 'city_name']]
# Out:
# Empty DataFrame
# Columns: [city_id, city_name]
# Index: []

# %%
clean_city_name(establishment_df, 'Henderson', 'city_name', 5)

# %%
establishment_df.loc[establishment_df['city_name'] == 'Las Vegas, NV 89103', 'city_name'] = 'Las Vegas'

# %%
establishment_df['city_name'].unique()
# Out:
# array(['Las Vegas', 'Blue Diamond', 'Henderson', 'North Las Vegas',
#        'Boulder City', 'Laughlin', 'Cal-Nev-Ari', 'Sandy Valley',
#        'Searchlight', 'Mesquite', 'Bunkerville', 'Overton', 'Logandale',
#        'Indian Springs', 'Mount Charleston', 'Goodsprings', 'Moapa',
#        'Primm', 'Jean', 'Spring Valley Mtns', 'Salt Lake City',
#        'Coyote Springs', 'St George', 'Shoshone', 'San Francisco',
#        'Honolulu', 'Pahrump', 'Arlington', 'Bakersfield', 'Apple Valley',
#        'Hansen', 'Laguna Hills', 'San Diego', 'Spokane', 'Palm Gardens',
#        'Lodi', 'Summerlin', 'Paradise Valley', 'Beaver Dam', 'MiESQUITE'],
#       dtype=object)

# %%
establishment_df = establishment_df[(establishment_df['city_name'] == 'North Las Vegas') | (establishment_df['city_name'] == 'Las Vegas') | (establishment_df['city_name'] == 'Henderson')]

# %%
establishment_df.loc[establishment_df['city_id'] == -1, ['city_id', 'city_name']]
# Out:
#        city_id        city_name
# 21087       -1        Las Vegas
# 25119       -1  North Las Vegas
# 25590       -1        Las Vegas
# 25820       -1        Las Vegas
# 25821       -1        Las Vegas
# 26020       -1        Las Vegas

# %%
business_df.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories'],
#       dtype='object')

# %%
b_df_words = []
for  k in business_df.name:
    k = k.lower()
    tokens = word_tokenize(k)
    words = [word for word in tokens if word.isalpha()]
    words = [w for w in words if not w in stop_words]
    b_df_words.extend(words)

# %%
esta_df_words = []
for  k in establishment_df.location_name:
    k= k.lower()
    tokens = word_tokenize(k)
    words = [word for word in tokens if word.isalpha()]
    words = [w for w in words if not w in stop_words]
    esta_df_words.extend(words)

# %%
pd.Series(b_df_words).value_counts()[:20]
# Out:
# bar           494
# cafe          458
# grill         448
# pizza         438
# restaurant    425
# vegas         235
# lounge        227
# taco          221
# kitchen       207
# las           203
# sushi         189
# starbucks     186
# shop          177
# mexican       171
# market        167
# house         161
# el            158
# express       153
# subway        153
# bbq           140
# dtype: int64

# %%
pd.Series(esta_df_words).value_counts()[0:20]
# Out:
# casino        4599
# hotel         3918
# vegas         1095
# las           1048
# resort        1010
# bar            717
# grill          687
# restaurant     675
# cafe           603
# grand          600
# center         567
# mgm            552
# ice            516
# pizza          488
# school         459
# el             430
# food           421
# deleted        420
# cream          410
# caesars        372
# dtype: int64

# %%
list_remove = ['bar','cafe','grill','casino','restaurant','hotel','resort','kitchen','pizza','lounge','bakery','shop','market']

# %%
def clean_text(x):
    temp = str(x)
    temp = temp.lower()
    tokens = word_tokenize(temp)
    words = [word for word in tokens if word.isalpha()]
    words = [w for w in words if not w in stop_words]
    words = [w for w in words if not w in list_remove]
    k= " ".join(words)
    return (k.strip())

# %%
clean_text(business_df.name[6])
# Out:
# 'imperial asian buffet'

# %%
business_df['clean_name'] = business_df.name.apply(lambda x : clean_text(x))

# %%
establishment_df['clean_rest_name'] = establishment_df.restaurant_name.apply(lambda x : clean_text(x))

# %%
establishment_df['clean_loc_name'] = establishment_df.location_name.apply(lambda x : clean_text(x))

# %%
def get_LCS(x,y):
    s = SequenceMatcher(lambda x: x==' ',x,y)
    match = s.find_longest_match(0, len(x), 0, len(y)) 
    if (len(x) >= len(y)):
        min_len = len(y)
    else: min_len = len(x)    
    lcs = x[match.a: match.a + match.size]
    return [lcs,len(lcs),len(lcs)/(min_len+1)]

# %%
get_LCS('','')[0]
# Out:
# ''

# %%
def get_nearest_list(x,df):
    df_filter = df[df.latitude.between(x.latitude -0.001,x.latitude+0.001) & df.longitude.between(x.longitude-0.001,x.longitude+0.001)]
    if (df_filter.shape[0] <=10) :
        df_filter = df[df.latitude.between(x.latitude -0.01,x.latitude+0.01) & df.longitude.between(x.longitude-0.01,x.longitude+0.01)]
    df_filter['business_name'] = x['name']
    df_filter['business_address'] = x['address']
    df_filter['lev_dist_normalized'] = df_filter['clean_loc_name'].apply(lambda y:editdistance.eval(x['clean_name'],y)/(len(x['clean_name'])+len(y)))
    df_filter[['LCS','LCS_len','LCS_normal']] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name']),axis =1 ,result_type ='expand')
    #df_filter['LCS_normal'] = df_filter['clean_rest_name'].apply(lambda y : (lcs.llcs(x['clean_name'], y))/(len(x['clean_name'])+len(y)))
    df_filter = df_filter.sort_values(by=['LCS_normal'],ascending = False)
    return df_filter[['location_name','clean_rest_name','facility_id','clean_loc_name','address','business_name','business_address','lev_dist_normalized','LCS','LCS_len','LCS_normal']]

# %%
get_nearest_list(business_df.iloc[22,],establishment_df)
# Out:
#                            location_name              clean_rest_name  \
# 20866  SUGARCANE RAW BAR AND GRILL @ GCS                    sugarcane
# 20867  SUGARCANE RAW BAR AND GRILL @ GCS   sugarcane warewash storage
# 20868  SUGARCANE RAW BAR AND GRILL @ GCS             sugarcane oyster
# 20869  SUGARCANE RAW BAR AND GRILL @ GCS                    sugarcane
# 20870  SUGARCANE RAW BAR AND GRILL @ GCS       sugarcane meeting room
# ...                                  ...                          ...
# 16496                 TILTED KILT @ LINQ                  tilted kilt
# 16497                 TILTED KILT @ LINQ                  tilted kilt
# 16498                 TILTED KILT @ LINQ             tilted kilt prep
# 16499                 TILTED KILT @ LINQ  tilted kilt servers station
# 5301                     WEST END MARKET           sports deli pantry
#
#       facility_id     clean_loc_name                address business_name  \
# 20866   FA0080177  sugarcane raw gcs       3377 S LAS VEGAS       Arc Bar
# 20867   FA0080177  sugarcane raw gcs       3377 S LAS VEGAS       Arc Bar
# 20868   FA0080177  sugarcane raw gcs       3377 S LAS VEGAS       Arc Bar
# 20869   FA0080177  sugarcane raw gcs       3377 S LAS VEGAS       Arc Bar
# 20870   FA0080177  sugarcane raw gcs       3377 S LAS VEGAS       Arc Bar
# ...           ...                ...                    ...           ...
# 16496   FA0071730   tilted kilt linq  3545 S LAS VEGAS Blvd       Arc Bar
# 16497   FA0071730   tilted kilt linq  3545 S LAS VEGAS Blvd       Arc Bar
# 16498   FA0071730   tilted kilt linq  3545 S LAS VEGAS Blvd       Arc Bar
# 16499   FA0071730   tilted kilt linq  3545 S LAS VEGAS Blvd       Arc Bar
# 5301    FA0005714           west end  3799 S Las Vegas Blvd       Arc Bar
#
#             business_address  lev_dist_normalized  LCS  LCS_len  LCS_normal
# 20866  3655 S Las Vegas Blvd             0.700000  arc        3        0.75
# 20867  3655 S Las Vegas Blvd             0.700000  arc        3        0.75
# 20868  3655 S Las Vegas Blvd             0.700000  arc        3        0.75
# 20869  3655 S Las Vegas Blvd             0.700000  arc        3        0.75
# 20870  3655 S Las Vegas Blvd             0.700000  arc        3        0.75
# ...                      ...                  ...  ...      ...         ...
# 16496  3655 S Las Vegas Blvd             0.842105             0        0.00
# 16497  3655 S Las Vegas Blvd             0.842105             0        0.00
# 16498  3655 S Las Vegas Blvd             0.842105             0        0.00
# 16499  3655 S Las Vegas Blvd             0.842105             0        0.00
# 5301   3655 S Las Vegas Blvd             0.727273             0        0.00
#
# [3566 rows x 11 columns]

# %%
def get_nearest_facid_name(x,df):
    df_filter = df[df['latitude'].between(x['latitude'] -0.001,x['latitude']+0.001) & df['longitude'].between(x['longitude']-0.001,x['longitude']+0.001)]
    if (df_filter.shape[0] <=10) :
        df_filter = df[df.latitude.between(x['latitude'] -0.01,x['latitude']+0.01) & df.longitude.between(x['longitude']-0.01,x['longitude']+0.01)]
    df_filter['business_name'] = x['name']
    df_filter['business_address'] = x['address']
    if df_filter.empty:
        return None   
    df_filter['lev_dist_normalized'] = df_filter['clean_loc_name'].apply(lambda y:editdistance.eval(x['clean_name'],y)/(len(x['clean_name'])+len(y)+1))
    df_filter['LCS'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[0],axis =1 ,result_type ='expand')
    df_filter['LCS_len'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[1],axis =1 ,result_type ='expand')         
    df_filter['LCS_normal'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[2],axis =1 ,result_type ='expand')
    #df_filter['LCS_normal'] = df_filter['clean_rest_name'].apply(lambda y : (lcs.llcs(x['clean_name'], y))/(len(x['clean_name'])+len(y)))
    df_filter = df_filter.sort_values(by=['LCS_normal'],ascending = False)
    ret = df_filter[df_filter.LCS_normal>0.5]
    if ret.empty:
        return None
    ret =ret['facility_id'].unique()
    return ret

# %%
get_nearest_facid_name(business_df.iloc[2,],establishment_df)

# %%
establishment_df.columns
# Out:
# Index(['permit_number', 'facility_id', 'owner_id', 'PE', 'restaurant_name',
#        'location_name', 'address', 'latitude', 'longitude', 'city_id',
#        'city_name', 'zip_code', 'nciaa', 'plan_review', 'record_status',
#        'current_grade', 'current_demerits', 'date_current', 'previous_grade',
#        'date_previous', 'search_text', 'city_', 'N_levi_dist', 'L_levi_dist',
#        'H_levi_dist', 'clean_rest_name', 'clean_loc_name'],
#       dtype='object')

# %%
establishment_df.isna().sum()
# Out:
# permit_number           0
# facility_id             0
# owner_id            24952
# PE                      0
# restaurant_name         2
# location_name           0
# address                13
# latitude                0
# longitude               0
# city_id                 0
# city_name               0
# zip_code               12
# nciaa                8078
# plan_review         24952
# record_status           0
# current_grade        1835
# current_demerits     1795
# date_current         1835
# previous_grade       1935
# date_previous        1935
# search_text             0
# city_                   0
# N_levi_dist             0
# L_levi_dist             0
# H_levi_dist             0
# clean_rest_name         0
# clean_loc_name          0
# dtype: int64

# %%
k=[]
for i in range(business_df.shape[0]):
    temp = get_nearest_facid_name(business_df.iloc[i,],establishment_df)
    k.append(temp)

# %%
business_df_key = pd.read_csv(r"C:/users/abdul/desktop/business_With_key1.csv")

# %%
business_df_key.head()
# Out:
#    Unnamed: 0                       address  \
# 0           0  1775 E Tropicana Ave, Ste 29
# 1           1           6007 Dean Martin Dr
# 2           2         6055 E Lake Mead Blvd
# 3           3               4190 N Pecos Rd
# 4           4       6125 Spring Mountain Rd
#
#                                           attributes             business_id  \
# 0  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...  PZ-LZzSlhSe9utkQYU8pFg
# 1  {'BikeParking': 'False', 'Ambience': "{'romant...  KWywu2tTEPWmR9JnBc0WyQ
# 2  {'BikeParking': 'True', 'BusinessParking': "{'...  tstimHoMcYbkSC4eBA1wEg
# 3  {'RestaurantsPriceRange2': '1', 'BusinessAccep...  NBn4hgfGtNz91k3VsDZlmw
# 4  {'RestaurantsPriceRange2': '1', 'Ambience': "{...  kANF0dbeoW34s2vwh6Umfw
#
#                                           categories       city  \
# 0                               Restaurants, Italian  Las Vegas
# 1  Nightlife, Arts & Entertainment, Bars, Strip C...  Las Vegas
# 2  Mexican, Restaurants, Patisserie/Cake Shop, Fo...  Las Vegas
# 3  Local Services, Food Banks, Community Service/...  Las Vegas
# 4  Fast Food, Food, Restaurants, Ice Cream & Froz...  Las Vegas
#
#                                                hours  is_open   latitude  \
# 0                                                NaN        0  36.100016
# 1  {'Thursday': '19:30-2:0', 'Friday': '19:30-3:0...        1  36.080168
# 2  {'Monday': '11:0-21:0', 'Tuesday': '10:0-21:0'...        1  36.195615
# 3  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...        1  36.236053
# 4                                                NaN        0  36.125031
#
#     longitude                                 name  postal_code  review_count  \
# 0 -115.128528           Carluccio's Tivoli Gardens      89119.0            40
# 1 -115.182756                         Hunk Mansion      89118.0           107
# 2 -115.040529  Maria's Mexican Restaurant & Bakery      89156.0           184
# 3 -115.096454                         Three Square      89115.0            44
# 4 -115.225620                          Dairy Queen      89146.0            33
#
#    stars                clean_name                        key
# 0    4.0  carluccio tivoli gardens  ['PR0009962' 'PR0009961']
# 1    4.0              hunk mansion                        NaN
# 2    4.5             maria mexican              ['PR0011933']
# 3    5.0              three square              ['PR0105994']
# 4    2.0               dairy queen              ['PR0017094']

# %%
business_df_key.shape
# Out:
# (10682, 16)

# %%
business_df_key.isna().sum()
# Out:
# Unnamed: 0         0
# address          205
# attributes       299
# business_id        0
# categories         0
# city               0
# hours           2514
# is_open            0
# latitude           0
# longitude          0
# name               0
# postal_code       23
# review_count       0
# stars              0
# clean_name       247
# key             4655
# dtype: int64

# %%
business_key_clean=business_df_key.dropna(subset=['key']).reset_index(drop= True)

# %%
business_key_clean.columns
# Out:
# Index(['Unnamed: 0', 'address', 'attributes', 'business_id', 'categories',
#        'city', 'hours', 'is_open', 'latitude', 'longitude', 'name',
#        'postal_code', 'review_count', 'stars', 'clean_name', 'key'],
#       dtype='object')

# %%
business_key_clean.head()
# Out:
#    Unnamed: 0                       address  \
# 0           0  1775 E Tropicana Ave, Ste 29
# 1           2         6055 E Lake Mead Blvd
# 2           3               4190 N Pecos Rd
# 3           4       6125 Spring Mountain Rd
# 4           5            3650 E Flamingo Rd
#
#                                           attributes             business_id  \
# 0  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...  PZ-LZzSlhSe9utkQYU8pFg
# 1  {'BikeParking': 'True', 'BusinessParking': "{'...  tstimHoMcYbkSC4eBA1wEg
# 2  {'RestaurantsPriceRange2': '1', 'BusinessAccep...  NBn4hgfGtNz91k3VsDZlmw
# 3  {'RestaurantsPriceRange2': '1', 'Ambience': "{...  kANF0dbeoW34s2vwh6Umfw
# 4  {'RestaurantsPriceRange2': '1', 'BusinessAccep...  YK5eFV8uS1bCmp8GeiQ-Qg
#
#                                           categories       city  \
# 0                               Restaurants, Italian  Las Vegas
# 1  Mexican, Restaurants, Patisserie/Cake Shop, Fo...  Las Vegas
# 2  Local Services, Food Banks, Community Service/...  Las Vegas
# 3  Fast Food, Food, Restaurants, Ice Cream & Froz...  Las Vegas
# 4                                       Food, Donuts  Las Vegas
#
#                                                hours  is_open   latitude  \
# 0                                                NaN        0  36.100016
# 1  {'Monday': '11:0-21:0', 'Tuesday': '10:0-21:0'...        1  36.195615
# 2  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...        1  36.236053
# 3                                                NaN        0  36.125031
# 4                                                NaN        0  36.115813
#
#     longitude                                 name  postal_code  review_count  \
# 0 -115.128528           Carluccio's Tivoli Gardens      89119.0            40
# 1 -115.040529  Maria's Mexican Restaurant & Bakery      89156.0           184
# 2 -115.096454                         Three Square      89115.0            44
# 3 -115.225620                          Dairy Queen      89146.0            33
# 4 -115.095457           All Star Donuts & Kolaches      89121.0             6
#
#    stars                clean_name                        key
# 0    4.0  carluccio tivoli gardens  ['PR0009962' 'PR0009961']
# 1    4.5             maria mexican              ['PR0011933']
# 2    5.0              three square              ['PR0105994']
# 3    2.0               dairy queen              ['PR0017094']
# 4    4.0      star donuts kolaches              ['PR0022046']

# %%
temp_test = business_key_clean.key

# %%
temp_test[0]
# Out:
# "['PR0009962' 'PR0009961']"

# %%
temp_test[7].split(' ')
# Out:
# ["['PR0118361']"]

# %%
business_key_clean.loc[7, business_key_clean.columns[::-1]]
# Out:
# key                                           FA0077104 FA0084247
# clean_name                                           bonjour deli
# stars                                                         4.5
# review_count                                                   39
# postal_code                                                 89103
# name                                        Bonjour Bakery & Deli
# longitude                                                -115.242
# latitude                                                  36.1162
# is_open                                                         1
# hours           {'Monday': '0:0-0:0', 'Tuesday': '8:0-15:0', '...
# city                                                    Las Vegas
# categories      Restaurants, Food, Delis, Desserts, Bakeries, ...
# business_id                                0G83H_zoum-Q4bWU2olTqQ
# attributes      {'WheelchairAccessible': 'True', 'RestaurantsD...
# address                                4012 S Rainbow Blvd, Ste J
# Name: 7, dtype: object

# %%
business_key_clean.loc[7, 'business_id']
# Out:
# '0G83H_zoum-Q4bWU2olTqQ'

# %%
expand_df = pd.DataFrame(columns= business_key_clean.columns )

# %%
expand_df
for i in business_key_clean.shape[0]:
# Out:
# Empty DataFrame
# Columns: [address, attributes, business_id, categories, city, hours, is_open, latitude, longitude, name, postal_code, review_count, stars, clean_name, key]
# Index: []

# %%
len(k)
# Out:
# 10682

# %%
temp=pd.Series(k)

# %%
business_df['key']=temp

# %%
business_df.key.isna().sum()
# Out:
# 5928

# %%
# business_df.to_csv('D:/down/business_With_key')

# %%
business_df.head()
# Out:
#               business_id                                 name  \
# 0  PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 1  KWywu2tTEPWmR9JnBc0WyQ                         Hunk Mansion
# 2  tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 3  NBn4hgfGtNz91k3VsDZlmw                         Three Square
# 4  kANF0dbeoW34s2vwh6Umfw                          Dairy Queen
#
#                         address       city state postal_code   latitude  \
# 0  1775 E Tropicana Ave, Ste 29  Las Vegas    NV       89119  36.100016
# 1           6007 Dean Martin Dr  Las Vegas    NV       89118  36.080168
# 2         6055 E Lake Mead Blvd  Las Vegas    NV       89156  36.195615
# 3               4190 N Pecos Rd  Las Vegas    NV       89115  36.236053
# 4       6125 Spring Mountain Rd  Las Vegas    NV       89146  36.125031
#
#     longitude  stars  review_count  is_open  \
# 0 -115.128529    4.0            40        0
# 1 -115.182756    4.0           107        1
# 2 -115.040529    4.5           184        1
# 3 -115.096454    5.0            44        1
# 4 -115.225620    2.0            33        0
#
#                                           attributes  \
# 0  {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 1  {'BikeParking': 'False', 'Ambience': '{'romant...
# 2  {'BikeParking': 'True', 'BusinessParking': '{'...
# 3  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4  {'RestaurantsPriceRange2': '1', 'Ambience': '{...
#
#                                           categories  \
# 0                               Restaurants, Italian
# 1  Nightlife, Arts & Entertainment, Bars, Strip C...
# 2  Mexican, Restaurants, Patisserie/Cake Shop, Fo...
# 3  Local Services, Food Banks, Community Service/...
# 4  Fast Food, Food, Restaurants, Ice Cream & Froz...
#
#                  clean_name          key
# 0  carluccio tivoli gardens  [FA0005923]
# 1              hunk mansion         None
# 2             maria mexican         None
# 3              three square  [FA0069108]
# 4               dairy queen         None

# %%
business_df.iloc[11,]['name']

# %%
def get_nearest_dist(x,df):
    dist =1000000000000000000
    name=''
    facility_id=''
    df_filter = df[df.latitude.between(x.latitude -0.001,x.latitude+0.001) & df.longitude.between(x.longitude-0.001,x.longitude+0.001)]
    for i in df_filter.index:
        distance = (df['latitude'][i]-x.latitude)**2 + (df['longitude'][i]-x.longitude)**2
        if(distance<dist ):
            name_in = df['location_name'][i]
            address_in = df['address'][i]
            facility_id = df['location_name'][i]
            dist = distance
    return [name_in,facility_id,address_in,dist]

# %%
def get_nearest_name(x,df):
    lev_dist =1000000000000000000
    name=''
    facility_id=''
    df_filter = df[df.latitude.between(x.latitude -0.001,x.latitude+0.001) & df.longitude.between(x.longitude-0.0005,x.longitude+0.0005)]
    for i in df_filter.index:
        lev_dist_temp = editdistance.eval(x['name'].lower(),df['location_name'][i].lower())
        if(lev_dist_temp<lev_dist ):
            lev_dist = lev_dist_temp
            name_in = df['location_name'][i]
            address_in = df['address'][i]
            facility_id = df['location_name'][i]
            distance = (df['latitude'][i]-x.latitude)**2 + (df['longitude'][i]-x.longitude)**2
    if (lev_dist<20):        
         return [lev_dist,name_in,facility_id,address_in,distance]
    else:
        return [None,None,None,None,None]

# %%
d = get_nearest_list(business_df.iloc[10,],establishment_df)
d

# %%
d[d.restaurant_name.str.contains("bistro",na=False) & d.address.str.contains("",na=False)]

# %%
d[d.location_name.str.contains("metro",na=False) & d.address.str.contains("",na=False)].facility_id.unique()

# %%
business_df_key = pd.read_csv('business_With_key1.csv')

# %%
business_df_key.drop(columns = 'Unnamed: 0', inplace = True)

# %%
business_key_clean = business_df_key.dropna(subset=['key']).reset_index(drop= True)

# %%
business_key_clean['key'] = business_key_clean['key'].apply(lambda x: re.sub("[\[''\]]",'', x))

# %%
new_df = []

# %%
for i in business_key_clean.index:
    for permit in business_key_clean.loc[i, 'key'].split(' '):
        new_df.append([business_key_clean.loc[i, 'business_id'], permit])

# %%
new_df = pd.DataFrame(new_df)

# %%
new_df[1] = new_df[1].apply(lambda x: x if '\n' not in x else x[:-2])

# %%
new_df.columns = ['business_id', 'permit_number']

# %%
bus_df = pd.read_csv('Cleaned Business.csv')

# %%
final_df = pd.merge(new_df, bus_df, on = 'business_id', how = 'inner')

# %%
est_df = pd.read_csv('Cleaned Establishement.csv')

# %%
final_df = pd.merge(final_df, est_df, on = 'permit_number', how = 'inner')

# %%
final_df.drop('Unnamed: 21', axis = 1, inplace = True)

# %%
final_df.head()
# Out:
#               business_id permit_number                                 name  \
# 0  PZ-LZzSlhSe9utkQYU8pFg     PR0009962           Carluccio's Tivoli Gardens
# 1  PZ-LZzSlhSe9utkQYU8pFg     PR0009961           Carluccio's Tivoli Gardens
# 2  tstimHoMcYbkSC4eBA1wEg     PR0011933  Maria's Mexican Restaurant & Bakery
# 3  NBn4hgfGtNz91k3VsDZlmw     PR0105994                         Three Square
# 4  kANF0dbeoW34s2vwh6Umfw     PR0017094                          Dairy Queen
#
#                       address_x       city state  postal_code  latitude_x  \
# 0  1775 E Tropicana Ave, Ste 29  Las Vegas    NV      89119.0   36.100016
# 1  1775 E Tropicana Ave, Ste 29  Las Vegas    NV      89119.0   36.100016
# 2         6055 E Lake Mead Blvd  Las Vegas    NV      89156.0   36.195615
# 3               4190 N Pecos Rd  Las Vegas    NV      89115.0   36.236053
# 4       6125 Spring Mountain Rd  Las Vegas    NV      89146.0   36.125031
#
#    longitude_x  stars  ...  city_name    zip_code nciaa record_status  \
# 0  -115.128528    4.0  ...  Las Vegas  89119-6529     Y             2
# 1  -115.128528    4.0  ...  Las Vegas  89119-6529     Y             2
# 2  -115.040529    4.5  ...  Las Vegas  89156-7801     Y             1
# 3  -115.096454    5.0  ...  Las Vegas       89115   NaN             2
# 4  -115.225620    2.0  ...  Las Vegas  89146-8802     Y             2
#
#   current_grade current_demerits         date_current previous_grade  \
# 0             A              4.0  2011-02-01 00:00:00              P
# 1             A             10.0  2011-02-01 00:00:00              P
# 2             A              6.0  2019-04-16 00:00:00              A
# 3             A              3.0  2019-01-22 00:00:00              A
# 4             A             10.0  2016-03-10 00:00:00              P
#
#          date_previous                                   search_text
# 0  2010-01-27 00:00:00  Carluccio's Lounge Bar Carluccios Lounge Bar
# 1  2010-01-27 00:00:00  Carluccio's Restaurant Carluccios Restaurant
# 2  2019-04-16 00:00:00                      Mama Maria's Mama Marias
# 3  2018-01-30 00:00:00   THREE SQUARE CATERING THREE SQUARE CATERING
# 4  2015-07-30 00:00:00          Dairy Queen #17798 Dairy Queen 17798
#
# [5 rows x 33 columns]

# %%
final_df.columns
# Out:
# Index(['business_id', 'permit_number', 'name', 'address_x', 'city', 'state',
#        'postal_code', 'latitude_x', 'longitude_x', 'stars', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours', 'facility_id', 'PE',
#        'restaurant_name', 'location_name', 'address_y', 'latitude_y',
#        'longitude_y', 'city_id', 'city_name', 'zip_code', 'nciaa',
#        'record_status', 'current_grade', 'current_demerits', 'date_current',
#        'previous_grade', 'date_previous', 'search_text'],
#       dtype='object')

# %%
check_df = final_df[['business_id', 'facility_id', 'address_x', 'name', 'location_name', 'restaurant_name', 'address_y']]

# %%
check_df.drop_duplicates(inplace = True)
# Out:
# C:\Users\kunke\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
check_df.to_csv('Current Check Mapping temp.csv', index = False)
