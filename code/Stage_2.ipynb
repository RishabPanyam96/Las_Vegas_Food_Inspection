# %% [markdown]
# ### Tokenization

# %%
import pandas as pd

# %%
yelp = pd.read_csv(r"C:/Users/abdul/Desktop/yelp_stage2.csv")
inspections = pd.read_csv(r"C:/Users/abdul/Desktop/Inspections_stage2.csv")

# %%
import nltk

# %%
# nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
yelp['tokenized'] = yelp.apply(lambda obs: nltk.word_tokenize(obs.text), axis=1)

# %%
yelp.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA  8mIrX_LrOnAqWsB5JrOojQ
# 1  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg  I4Nr-MVc26qWr08-S3Q1ow
# 2  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA  d_L-rfS1vT3JMzgCUGtiow
# 3  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ  Sfc8Haz2Yri8Mo1L0E0TsA
# 4  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw  Gyrez6K8f1AyR7dzW9fvAw
#
#    stars  useful  funny  cool  \
# 0    4.0       0      0     0
# 1    4.0       0      0     0
# 2    5.0       0      0     0
# 3    5.0       0      0     0
# 4    5.0       0      0     1
#
#                                                 text                 date  \
# 0  Like walking back in time, every Saturday morn...  2011-11-30 02:11:15
# 1  The food is always good and the prices are rea...  2016-01-17 05:26:22
# 2  Pick any meat on the planet and the chef will ...  2016-07-25 03:57:19
# 3  Great food, great service. Obviously fried chi...  2012-11-06 03:41:43
# 4  their pettuccine was fresh-made in the morning...  2013-12-28 22:28:08
#
#                    name  ... postal_code   latitude   longitude  stars_b  \
# 0  Pinball Hall Of Fame  ...     89119.0  36.101449 -115.130511      4.5
# 1      Greenberg's Deli  ...     89136.0  36.102379 -115.174547      4.0
# 2          Border Grill  ...     89119.0  36.090067 -115.176973      4.0
# 3          Chicken Bonz  ...     89118.0  36.071196 -115.207463      3.0
# 4              Casanova  ...     89109.0  36.121579 -115.168664      4.0
#
#    review_count  is_open                                         attributes  \
# 0        1258.0      1.0  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 1         333.0      1.0  {'RestaurantsPriceRange2': '2', 'HasTV': 'Fals...
# 2        1623.0      1.0  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'Tru...
# 3          52.0      0.0  {'Ambience': "{'romantic': False, 'intimate': ...
# 4         495.0      1.0  {'HasTV': 'True', 'Ambience': "{'romantic': Fa...
#
#                                           categories  \
# 0  Performing Arts, Amusement Parks, Museums, Arc...
# 1              Delis, Sandwiches, Pizza, Restaurants
# 2  Breakfast & Brunch, Restaurants, Tapas/Small P...
# 3                Chicken Wings, Burgers, Restaurants
# 4    Restaurants, Tapas Bars, Mediterranean, Italian
#
#                                                hours  \
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 2  {'Monday': '10:0-22:0', 'Tuesday': '11:0-22:0'...
# 3  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 4  {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
#
#                                            tokenized
# 0  [Like, walking, back, in, time, ,, every, Satu...
# 1  [The, food, is, always, good, and, the, prices...
# 2  [Pick, any, meat, on, the, planet, and, the, c...
# 3  [Great, food, ,, great, service, ., Obviously,...
# 4  [their, pettuccine, was, fresh-made, in, the, ...
#
# [5 rows x 23 columns]

# %%
yelp.iloc[1].tokenized
# Out:
# ['The',
#  'food',
#  'is',
#  'always',
#  'good',
#  'and',
#  'the',
#  'prices',
#  'are',
#  'reasonable',
#  '.',
#  'Although',
#  'it',
#  "'s",
#  'not',
#  'exactly',
#  'a',
#  'restaurant',
#  '--',
#  'more',
#  'like',
#  'a',
#  'snack',
#  'bar',
#  ',',
#  'limited',
#  'menu',
#  'and',
#  'you',
#  'walk',
#  'up',
#  'to',
#  'the',
#  'counter',
#  ',',
#  'place',
#  'your',
#  'order',
#  ',',
#  'wait',
#  'a',
#  'minute',
#  'or',
#  'so',
#  'for',
#  'them',
#  'to',
#  'prepare',
#  'your',
#  'order',
#  ',',
#  'and',
#  'pay',
#  'the',
#  'cashier',
#  ',',
#  'then',
#  'search',
#  'for',
#  'a',
#  'table',
#  '.',
#  'Kind',
#  'of',
#  'like',
#  'a',
#  'sandwich',
#  'shop',
#  '.',
#  'Still',
#  'a',
#  'much',
#  'better',
#  'choice',
#  'for',
#  'value',
#  'than',
#  'the',
#  'other',
#  'hotel',
#  'Deli',
#  "'s",
#  'on',
#  'the',
#  'strip',
#  '.']

# %%
yelp = yelp.reset_index()

# %%
yelp['review_length'] = yelp.apply(lambda obs: len(obs.tokenized), axis=1)

# %%
yelp.head()
# Out:
#    index               review_id                 user_id  \
# 0      0  kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA
# 1      1  IByf6mVY0WA838XNSh-5MA  3CJUJILq7CLHk_9OrvpvQg
# 2      2  S337tATeouQJdoPYyir29w  2mxBNBeFrgDszqGS5tdEHA
# 3      3  D_UvaenM25iNd6aehTZ0MA  8NwU4TRsD3S6gIfBqFzDMQ
# 4      4  qm97yMwREr7BKkexlwLFbg  TTRVdTXKcq-xn6-1IWbwEw
#
#               business_id  stars  useful  funny  cool  \
# 0  8mIrX_LrOnAqWsB5JrOojQ    4.0       0      0     0
# 1  I4Nr-MVc26qWr08-S3Q1ow    4.0       0      0     0
# 2  d_L-rfS1vT3JMzgCUGtiow    5.0       0      0     0
# 3  Sfc8Haz2Yri8Mo1L0E0TsA    5.0       0      0     0
# 4  Gyrez6K8f1AyR7dzW9fvAw    5.0       0      0     1
#
#                                                 text                 date  \
# 0  Like walking back in time, every Saturday morn...  2011-11-30 02:11:15
# 1  The food is always good and the prices are rea...  2016-01-17 05:26:22
# 2  Pick any meat on the planet and the chef will ...  2016-07-25 03:57:19
# 3  Great food, great service. Obviously fried chi...  2012-11-06 03:41:43
# 4  their pettuccine was fresh-made in the morning...  2013-12-28 22:28:08
#
#    ...   latitude   longitude stars_b review_count  is_open  \
# 0  ...  36.101449 -115.130511     4.5       1258.0      1.0
# 1  ...  36.102379 -115.174547     4.0        333.0      1.0
# 2  ...  36.090067 -115.176973     4.0       1623.0      1.0
# 3  ...  36.071196 -115.207463     3.0         52.0      0.0
# 4  ...  36.121579 -115.168664     4.0        495.0      1.0
#
#                                           attributes  \
# 0  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 1  {'RestaurantsPriceRange2': '2', 'HasTV': 'Fals...
# 2  {'WiFi': "u'free'", 'RestaurantsTakeOut': 'Tru...
# 3  {'Ambience': "{'romantic': False, 'intimate': ...
# 4  {'HasTV': 'True', 'Ambience': "{'romantic': Fa...
#
#                                           categories  \
# 0  Performing Arts, Amusement Parks, Museums, Arc...
# 1              Delis, Sandwiches, Pizza, Restaurants
# 2  Breakfast & Brunch, Restaurants, Tapas/Small P...
# 3                Chicken Wings, Burgers, Restaurants
# 4    Restaurants, Tapas Bars, Mediterranean, Italian
#
#                                                hours  \
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 2  {'Monday': '10:0-22:0', 'Tuesday': '11:0-22:0'...
# 3  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 4  {'Monday': '8:0-23:0', 'Tuesday': '8:0-23:0', ...
#
#                                            tokenized  review_length
# 0  [Like, walking, back, in, time, ,, every, Satu...            145
# 1  [The, food, is, always, good, and, the, prices...             86
# 2  [Pick, any, meat, on, the, planet, and, the, c...             35
# 3  [Great, food, ,, great, service, ., Obviously,...             49
# 4  [their, pettuccine, was, fresh-made, in, the, ...             39
#
# [5 rows x 25 columns]

# %%
# histogram of word length
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(20,8))
sns.distplot(yelp.review_length, kde=False, color='blue')
plt.show()

# %%
yelp.review_length.mean()
# Out:
# 127.07911478117258

# %%
yelp.review_length.median()
# Out:
# 88.0

# %% [markdown]
# ### We probably should take out punctuations
