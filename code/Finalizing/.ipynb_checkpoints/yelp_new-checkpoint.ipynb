# %%
import pandas as pd
import numpy as np
import json

# %%
from nltk import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
from difflib import SequenceMatcher

# %%
import warnings
warnings.simplefilter('ignore')

# %%
import re

# %%
# pip install editdistance
# Out:
# Requirement already satisfied: editdistance in c:\users\13129\appdata\local\continuum\anaconda3\lib\site-packages (0.5.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import editdistance
import nltk

# %%
# initalizing links for our files
business_data_google = 'D:/down/business_df.csv'
business_data_url = 'D:/down/yelpdataset/business.json'
inspection_data_url = 'D:/down/restaurants/restaurant_inspections.csv'
inspection_rest_url = 'D:/down/restaurants/restaurant_establishments.csv'
review_data_url = 'D:/down/yelpdataset/review.json'

# %%
business_df = pd.read_json(business_data_url,lines =True)
# reading in the business_file

# %%
def get_levinshtein_distance_city(df, city_name, city_column_name):
    df['city_'] = df[city_column_name].apply(lambda x: x.lower().strip().title())
    column_name = city_name[:1] + '_levi_dist'
    df[column_name] = df.loc[:, 'city_'].apply(lambda x: editdistance.eval(x, city_name))
# function to get levensitein distance for each row of the dataframe

# %%
def clean_city_name(df, replace_with, city_column_name, cutoff):
    column_name = replace_with[:1] + '_levi_dist'
    df.loc[df[column_name] < cutoff, city_column_name] = replace_with
#get clean city name for each columns

# %%
business_df.drop(business_df.columns[-1], axis = 1, inplace = True)

# %%
get_levinshtein_distance_city(business_df, 'North Las Vegas', 'city')

# %%
business_df = business_df[business_df['city_'] != 'South Las Vegas']

# %%
business_df[(business_df['N_levi_dist'] < 5) & (business_df['N_levi_dist'] > 0)]
# LV distance for North Las Vegas
# Out:
#                                address  \
# 12686     3435 W Cheyenne Ave, Ste 102
# 17423             1360 W. Cheyenne Ave
# 23849           3365 W Craig Rd, Ste 8
# 29864           4837 Lincoln Rd, Ste E
# 30998                   190 W Craig Rd
# 39306
# 48752                 918 Sharp Circle
# 55829                2445 W Craig Road
# 69308      4357 Corporate Ctr, Ste 490
# 71027             5536 Camino Al Norte
# 78405               2465 N Nellis Blvd
# 81607                    2516 Losee Rd
# 91435           2696 W Ann Rd, Ste 110
# 91500                  3830 E Craig Rd
# 109536      3425 W Lake Meade, Ste 105
# 116290             2001 E Cheyenne Ave
# 117619   2415 N. Las Vegas Blvd., #101
# 118288
# 120414           4417 Misty Breeze Cir
# 121673         1306 W Craig Rd, Ste B1
# 132494                 1321 W Craig Rd
# 132534           1616 E Lake Mead Blvd
# 133828           1842 Las Vegas Blvd N
# 133980      580 W Cheyenne Ave, Ste 40
# 134901                   5625 Losee Rd
# 139277             6505 Doby Peak Road
# 143069               2531 E Craig Rd N
# 152015              3415 Bellington Rd
# 153190                 5585 Simmons St
# 155664             2975 Coleman Street
# 156493          2707 E Craig Rd, Ste B
# 157954              2101 Texas Star Ln
# 163804            4780 W Ann Rd, Ste 5
# 165255                  North Mesa Plz
# 168007              6050 West Craig Rd
# 170354                924 E Colton Ave
# 172475               6960 North 5th St
# 178023  3425 W Lake Mead Blvd, Ste 105
# 180746   5175 Camino Al Norte, Ste 100
# 186720          3776 W Ann Rd, Ste 155
#
#                                                attributes  \
# 12686                                                None
# 17423   {'RestaurantsGoodForGroups': 'False', 'WiFi': ...
# 23849   {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 29864   {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 30998   {'Caters': 'True', 'Music': '{'dj': False, 'ba...
# 39306                                                None
# 48752   {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 55829                                                None
# 69308                                                None
# 71027   {'BusinessParking': '{'garage': False, 'street...
# 78405   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 81607             {'BusinessAcceptsCreditCards': 'False'}
# 91435   {'BusinessParking': '{'garage': False, 'street...
# 91500              {'BusinessAcceptsCreditCards': 'True'}
# 109536  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 116290  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 117619  {'BusinessParking': '{'garage': False, 'street...
# 118288  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 120414  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 121673  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 132494                                               None
# 132534  {'RestaurantsReservations': 'False', 'Restaura...
# 133828  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 133980             {'BusinessAcceptsCreditCards': 'True'}
# 134901  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 139277  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 143069  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 152015  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 153190  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 155664  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 156493                                               None
# 157954  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 163804             {'BusinessAcceptsCreditCards': 'True'}
# 165255  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 168007  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 170354  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 172475  {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 178023                                               None
# 180746                                               None
# 186720                            {'GoodForKids': 'True'}
#
#                    business_id  \
# 12686   m09U1hgWg94Z-9iyVuOkYA
# 17423   zBlh5vP_qkSNR5Cc6lWG4w
# 23849   f1uziLh9BeWsm5SBUmsPqg
# 29864   l8WJ-Imy2FqHuZ1T2utTcw
# 30998   Y7T9osP-hoqp2nLnmIi12w
# 39306   zdxKXLJR1obxtkSGlwaThw
# 48752   ldbgYzpbXMZ3MD7PYoZLWA
# 55829   vQU7ed_nxfY94MLhs5ii_Q
# 69308   EcHm_jsbFJMnBmRr_ji8Vw
# 71027   ttsLdrsKe24vXZcmZXcZ4g
# 78405   Ua1fGA87fa5xhnitZwoV5g
# 81607   bB9RVbFrixBg_-CldjFk5g
# 91435   ES9SowkyQSvVG-5LNTK-1A
# 91500   O-nd3gw4A13i1pdKpr_Gkg
# 109536  QFR-ty1CPMCirSnZuZ5ayw
# 116290  j4nX7yJFULEXXjMKBLwDLw
# 117619  WPM5eDqWmCYpRDcG3ihRGg
# 118288  c7-gIO71adWmNjj9tz-ugQ
# 120414  ZXxi3Xu4ZYcdzZ4BrBirBQ
# 121673  zI5hl38DTxXv3RHCJqBmbQ
# 132494  xbdv7He4jVk53sX9deBM3w
# 132534  Jfnb9IDQ326omYqA-buX_w
# 133828  SUgldud8wiwCg5tkULepBQ
# 133980  z3oRicoIlFsja9YnhezHfg
# 134901  k2z2c-opKwIbsTpg-R0BYg
# 139277  EDwRybg4pgqINVHax_XeAg
# 143069  dbKnvc3eAugC-vRxw03Jzw
# 170354  Gardeners, Home Services, Tree Services, Lands...   N. Las Vegas
# 172475  Flowers & Gifts, Cards & Stationery, Event Pla...    N Las Vegas
# 178023                            Automotive, Auto Repair    N Las Vegas
# 180746  First Aid Classes, Specialty Schools, Educatio...   N. Las Vegas
# 186720  Trainers, Fitness & Instruction, Boot Camps, G...    N Las Vegas
#
#                                                     hours  is_open   latitude  \
# 12686   {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...        1  36.217025
# 17423   {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...        1  36.218024
# 23849   {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.238022
# 29864   {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...        1  36.248214
# 30998   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.240007
# 39306                                                None        0  36.260816
# 48752   {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...        1  36.219840
# 55829   {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...        1  36.239170
# 69308   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  36.239545
# 71027                                                None        1  36.260662
# 78405   {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...        1  36.204528
# 81607   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.205325
# 91435   {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.262327
# 91500   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  36.240701
# 109536  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...        1  36.197083
# 116290  {'Monday': '8:30-22:30', 'Tuesday': '8:30-22:3...        1  36.217365
# 117619                                               None        1  36.204060
# 118288  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...        1  36.214454
# 120414  {'Monday': '7:0-19:0', 'Tuesday': '7:0-19:0', ...        1  36.234236
# 121673  {'Monday': '9:30-19:0', 'Wednesday': '9:30-19:...        1  36.240949
# 132494  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        1  36.237894
# 132534                                               None        0  36.196140
# 133828  {'Thursday': '21:30-3:0', 'Friday': '21:30-4:0...        1  36.193216
# 133980  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.214518
# 134901  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        1  36.262123
# 139277  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        0  36.241144
# 143069                                               None        1  36.239368
# 152015  {'Monday': '0:0-0:0', 'Tuesday': '7:0-16:0', '...        1  36.229929
# 153190                                               None        0  36.261223
# 155664  {'Monday': '5:0-18:30', 'Tuesday': '5:0-18:30'...        1  36.212938
# 156493                                               None        1  36.239386
# 157954  {'Monday': '7:0-2:0', 'Tuesday': '7:0-2:0', 'W...        1  36.198360
# 163804  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:0', '...        1  36.262525
# 165255  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        0  36.238192
# 168007  {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...        1  36.241157
# 170354  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  36.221502
# 172475  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...        1  36.286925
# 178023                                               None        1  36.196622
# 180746  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.253939
# 186720  {'Monday': '6:0-17:30', 'Tuesday': '7:0-17:30'...        0  36.261583
#
#          longitude                                        name postal_code  \
# 12686  -115.185241               Nevada Orthotics & Prosthetic       89032
# 17423  -115.159586                        Little Caesars Pizza       89030
# 23849  -115.185303                             The Tech Monkey       89032
# 29864  -115.085057                                JDS Surfaces       89081
# 30998  -115.142244                          Buffalo Wild Wings       89032
# 39306  -115.171130                  Blue Brothers Pool Service       89031
# 48752  -115.128754                       Infinity Custom Glass       89030
# 55829  -115.175959                          Dollar Loan Center       89032
# 69308  -115.099186  Mike Whitford - State Farm Insurance Agent       89030
# 170354             8    3.5   N. Las Vegas            4
# 172475            23    3.5    N Las Vegas            4
# 178023             3    2.5    N Las Vegas            4
# 180746             6    4.5   N. Las Vegas            4
# 186720            12    4.5    N Las Vegas            4

# %%
get_levinshtein_distance_city(business_df, 'Las Vegas', 'city')

# %%
clean_city_name(business_df, 'North Las Vegas', 'city', 5)

# %%
business_df[(business_df['L_levi_dist'] < 5) & (business_df['L_levi_dist'] > 0)]
# Lv distance for Las Vegas
# Out:
#                                          address  \
# 3993           10300 Charleston Blvd, Ste 13-473
# 12686               3435 W Cheyenne Ave, Ste 102
# 17423                       1360 W. Cheyenne Ave
# 23849                     3365 W Craig Rd, Ste 8
# 28686
# 29864                     4837 Lincoln Rd, Ste E
# 30998                             190 W Craig Rd
# 39306
# 47208
# 48752                           918 Sharp Circle
# 49456                4431 S Eastern Ave, Ste 250
# 55829                          2445 W Craig Road
# 63321                           6415 Fort Apache
# 65197                        1801 S Rainbow Blvd
# 69308                4357 Corporate Ctr, Ste 490
# 71027                       5536 Camino Al Norte
# 74494                  120 E Bruner Ave, Ste 120
# 77692                     4625 W Charleston Blvd
# 78405                         2465 N Nellis Blvd
# 81607                              2516 Losee Rd
# 85872
# 88219   Fashion Show Mall, 3200 Las Vegas Blvd S
# 89357
# 89945                      3400 Las Vegas Blvd S
# 91435                     2696 W Ann Rd, Ste 110
# 91500                            3830 E Craig Rd
# 98671                      4104 E Lake Mead Blvd
# 105458                       2550 S Rainbow Blvd
# 109536                3425 W Lake Meade, Ste 105
# 116290                       2001 E Cheyenne Ave
# 117619             2415 N. Las Vegas Blvd., #101
# 118288
# 120414                     4417 Misty Breeze Cir
# 121673                   1306 W Craig Rd, Ste B1
# 132494                           1321 W Craig Rd
# 132534                     1616 E Lake Mead Blvd
# 133828                     1842 Las Vegas Blvd N
# 133980                580 W Cheyenne Ave, Ste 40
# 134901                             5625 Losee Rd
# 139277                       6505 Doby Peak Road
# 142829             9827 W Tropicana Ave, Ste 100
# 143069                         2531 E Craig Rd N
# 151045                        6745 S Eastern Ave
# 152015                        3415 Bellington Rd
# 153190                           5585 Simmons St
# 155664                       2975 Coleman Street
# 156493                    2707 E Craig Rd, Ste B
# 157954                        2101 Texas Star Ln
# 161165               777 N Rainbow Blvd, Ste 270
# 163804                      4780 W Ann Rd, Ste 5
# 165255                            North Mesa Plz
# 168007                        6050 West Craig Rd
# 169862                   3533 S Valley View Blvd
# 170354                          924 E Colton Ave
# 172475                         6960 North 5th St
# 178023            3425 W Lake Mead Blvd, Ste 105
# 179012                     3790 Las Vegas Blvd S
# 180746             5175 Camino Al Norte, Ste 100
# 186720                    3776 W Ann Rd, Ste 155
# 188956             340 South Jones Blvd, Ste 274
#
#                                                attributes  \
# 3993    {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 12686                                                None
# 17423   {'RestaurantsGoodForGroups': 'False', 'WiFi': ...
# 23849   {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 28686                                                None
# 29864   {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 30998   {'Caters': 'True', 'Music': '{'dj': False, 'ba...
# 39306                                                None
# 47208   {'BikeParking': 'True', 'ByAppointmentOnly': '...
# 48752   {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 49456   {'BusinessAcceptsCreditCards': 'False', 'Busin...
# 55829                                                None
# 63321   {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 65197   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 69308                                                None
# 71027   {'BusinessParking': '{'garage': False, 'street...
# 74494   {'BusinessParking': '{'garage': False, 'street...
# 77692   {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 78405   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 81607             {'BusinessAcceptsCreditCards': 'False'}
# 85872   {'BusinessParking': '{'garage': True, 'street'...
# 88219   {'RestaurantsPriceRange2': '3', 'BusinessParki...
# 89357              {'BusinessAcceptsCreditCards': 'True'}
# 89945   {'DriveThru': 'False', 'Ambience': '{'romantic...
# 91435   {'BusinessParking': '{'garage': False, 'street...
# 91500              {'BusinessAcceptsCreditCards': 'True'}
# 98671   {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 105458  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 109536  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 116290  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 117619  {'BusinessParking': '{'garage': False, 'street...
# 118288  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 120414  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 121673  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 132494                                               None
# 132534  {'RestaurantsReservations': 'False', 'Restaura...
# 133828  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 133980             {'BusinessAcceptsCreditCards': 'True'}
# 134901  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 139277  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 142829             {'BusinessAcceptsCreditCards': 'True'}
# 143069  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 151045                           {'GoodForKids': 'False'}
# 152015  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 153190  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 155664  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 156493                                               None
# 157954  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 161165                                               None
# 163804             {'BusinessAcceptsCreditCards': 'True'}
# 165255  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 168007  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 169862  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 170354  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 172475  {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 178023                                               None
# 179012  {'BusinessAcceptsCreditCards': 'True', 'CoatCh...
# 180746                                               None
# 186720                            {'GoodForKids': 'True'}
# 188956                                               None
#
#                    business_id  \
# 3993    d20nYbRK7_TRRofOpzRZNQ
# 12686   m09U1hgWg94Z-9iyVuOkYA
# 17423   zBlh5vP_qkSNR5Cc6lWG4w
# 23849   f1uziLh9BeWsm5SBUmsPqg
# 28686   QVFfbOZBtIEH0VretoMXLQ
# 29864   l8WJ-Imy2FqHuZ1T2utTcw
# 30998   Y7T9osP-hoqp2nLnmIi12w
# 39306   zdxKXLJR1obxtkSGlwaThw
# 47208   t8xvlKk5axVYy2c2p70NRg
# 48752   ldbgYzpbXMZ3MD7PYoZLWA
# 49456   6E5SM3-YvBpdzNNW68ksTw
# 55829   vQU7ed_nxfY94MLhs5ii_Q
# 63321   sOQBfSKH9EXM6nRgtGaE3w
# 65197   oQraEYPdsFyjs-Q_Dmn4uw
# 69308   EcHm_jsbFJMnBmRr_ji8Vw
# 71027   ttsLdrsKe24vXZcmZXcZ4g
# 74494   axYby0KsY2PsfGv_HzAe9g
# 77692   5DetOjfJ_d3qvAP0WbdOSw
# 78405   Ua1fGA87fa5xhnitZwoV5g
# 186720  Trainers, Fitness & Instruction, Boot Camps, G...  North Las Vegas
# 188956  Hair Loss Centers, Hair Salons, Beauty & Spas,...       Las Vergas
#
#                                                     hours  is_open   latitude  \
# 3993    {'Monday': '8:0-19:0', 'Tuesday': '8:0-19:30',...        1  36.160569
# 12686   {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...        1  36.217025
# 17423   {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...        1  36.218024
# 23849   {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.238022
# 28686                              {'Monday': '9:0-17:0'}        1  36.198854
# 29864   {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...        1  36.248214
# 30998   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.240007
# 39306                                                None        0  36.260816
# 47208   {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.169941
# 48752   {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...        1  36.219840
# 49456   {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...        1  36.028157
# 55829   {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...        1  36.239170
# 63321   {'Tuesday': '10:0-18:0', 'Wednesday': '10:0-18...        1  36.071521
# 65197   {'Monday': '9:30-19:30', 'Tuesday': '9:30-19:3...        1  36.151333
# 69308   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  36.239545
# 71027                                                None        1  36.260662
# 74494                                                None        0  35.970741
# 77692   {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...        1  36.156263
# 78405   {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...        1  36.204528
# 81607   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.205325
# 85872   {'Tuesday': '18:0-22:0', 'Wednesday': '18:0-22...        1  36.169710
# 88219   {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...        1  36.127524
# 89357                                                None        1  36.169941
# 89945   {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...        1  36.120269
# 91435   {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  36.262327
# 91500   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  36.240701
# 98671   {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...        1  36.195983
# 105458  {'Monday': '0:0-0:0', 'Tuesday': '10:0-22:0', ...        1  36.143104
# 109536  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...        1  36.197083
# 116290  {'Monday': '8:30-22:30', 'Tuesday': '8:30-22:3...        1  36.217365
# 117619                                               None        1  36.204060
# 118288  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...        1  36.214454
# 120414  {'Monday': '7:0-19:0', 'Tuesday': '7:0-19:0', ...        1  36.234236
# 121673  {'Monday': '9:30-19:0', 'Wednesday': '9:30-19:...        1  36.240949
# 132494  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        1  36.237894
# 132534                                               None        0  36.196140
# 133828  {'Thursday': '21:30-3:0', 'Friday': '21:30-4:0...        1  36.193216
# 133980  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.214518
# 134901  {'Monday': '9:0-21:0', 'Tuesday': '9:0-21:0', ...        1  36.262123
# 139277  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        0  36.241144
# 142829  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...        0  36.099575
# 143069                                               None        1  36.239368
# 151045  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...        1  36.068425
# 152015  {'Monday': '0:0-0:0', 'Tuesday': '7:0-16:0', '...        1  36.229929
# 153190                                               None        0  36.261223
# 155664  {'Monday': '5:0-18:30', 'Tuesday': '5:0-18:30'...        1  36.212938
# 156493                                               None        1  36.239386
# 157954  {'Monday': '7:0-2:0', 'Tuesday': '7:0-2:0', 'W...        1  36.198360
# 161165  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# 170354       89030             8    3.5   N. Las Vegas            4
# 172475       89084            23    3.5    N Las Vegas            4
# 178023       89032             3    2.5    N Las Vegas            4
# 179012       89109             5    4.5       Lasvegas            8
# 180746       89031             6    4.5   N. Las Vegas            4
# 186720       89031            12    4.5    N Las Vegas            4
# 188956       89107             3    5.0     Las Vergas            7
#
#         L_levi_dist
# 3993              1
# 12686             3
# 17423             3
# 23849             2
# 28686             1
# 29864             3
# 30998             3
# 39306             2
# 47208             3
# 48752             2
# 49456             3
# 55829             3
# 63321             4
# 65197             4
# 69308             2
# 71027             2
# 74494             1
# 77692             2
# 78405             4
# 81607             2
# 85872             1
# 88219             4
# 89357             1
# 89945             2
# 91435             2
# 91500             2
# 98671             1
# 105458            1
# 109536            3
# 116290            2
# 117619            3
# 118288            2
# 120414            2
# 121673            2
# 132494            2
# 132534            2
# 133828            2
# 133980            2
# 134901            2
# 139277            2
# 142829            4
# 143069            2
# 151045            1
# 152015            3
# 153190            2
# 155664            3
# 156493            3
# 157954            2
# 161165            1
# 163804            2
# 165255            2
# 168007            4
# 169862            1
# 170354            3
# 172475            2
# 178023            2
# 179012            2
# 180746            3
# 186720            2
# 188956            1

# %%
clean_city_name(business_df, 'Las Vegas', 'city', 5)

# %%
business_df[(business_df['L_levi_dist'] < 5) & (business_df['L_levi_dist'] > 0)]
# Out:
#                                          address  \
# 3993           10300 Charleston Blvd, Ste 13-473
# 12686               3435 W Cheyenne Ave, Ste 102
# 17423                       1360 W. Cheyenne Ave
# 23849                     3365 W Craig Rd, Ste 8
# 28686
# 29864                     4837 Lincoln Rd, Ste E
# 30998                             190 W Craig Rd
# 39306
# 47208
# 48752                           918 Sharp Circle
# 49456                4431 S Eastern Ave, Ste 250
# 55829                          2445 W Craig Road
# 63321                           6415 Fort Apache
# 65197                        1801 S Rainbow Blvd
# 69308                4357 Corporate Ctr, Ste 490
# 71027                       5536 Camino Al Norte
# 74494                  120 E Bruner Ave, Ste 120
# 77692                     4625 W Charleston Blvd
# 78405                         2465 N Nellis Blvd
# 81607                              2516 Losee Rd
# 85872
# 88219   Fashion Show Mall, 3200 Las Vegas Blvd S
# 89357
# 89945                      3400 Las Vegas Blvd S
# 91435                     2696 W Ann Rd, Ste 110
# 91500                            3830 E Craig Rd
# 98671                      4104 E Lake Mead Blvd
# 105458                       2550 S Rainbow Blvd
# 109536                3425 W Lake Meade, Ste 105
# 116290                       2001 E Cheyenne Ave
# 117619             2415 N. Las Vegas Blvd., #101
# 118288
# 120414                     4417 Misty Breeze Cir
# 121673                   1306 W Craig Rd, Ste B1
# 132494                           1321 W Craig Rd
# 132534                     1616 E Lake Mead Blvd
# 133828                     1842 Las Vegas Blvd N
# 133980                580 W Cheyenne Ave, Ste 40
# 134901                             5625 Losee Rd
# 139277                       6505 Doby Peak Road
# 142829             9827 W Tropicana Ave, Ste 100
# 143069                         2531 E Craig Rd N
# 151045                        6745 S Eastern Ave
# 152015                        3415 Bellington Rd
# 153190                           5585 Simmons St
# 155664                       2975 Coleman Street
# 156493                    2707 E Craig Rd, Ste B
# 157954                        2101 Texas Star Ln
# 161165               777 N Rainbow Blvd, Ste 270
# 163804                      4780 W Ann Rd, Ste 5
# 165255                            North Mesa Plz
# 168007                        6050 West Craig Rd
# 169862                   3533 S Valley View Blvd
# 170354                          924 E Colton Ave
# 172475                         6960 North 5th St
# 178023            3425 W Lake Mead Blvd, Ste 105
# 179012                     3790 Las Vegas Blvd S
# 180746             5175 Camino Al Norte, Ste 100
# 186720                    3776 W Ann Rd, Ste 155
# 188956             340 South Jones Blvd, Ste 274
#
#                                                attributes  \
# 3993    {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 12686                                                None
# 17423   {'RestaurantsGoodForGroups': 'False', 'WiFi': ...
# 23849   {'ByAppointmentOnly': 'False', 'BusinessAccept...
# 28686                                                None
# 29864   {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 30998   {'Caters': 'True', 'Music': '{'dj': False, 'ba...
# 39306                                                None
# 47208   {'BikeParking': 'True', 'ByAppointmentOnly': '...
# 48752   {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 49456   {'BusinessAcceptsCreditCards': 'False', 'Busin...
# 55829                                                None
# 63321   {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 65197   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 69308                                                None
# 71027   {'BusinessParking': '{'garage': False, 'street...
# 74494   {'BusinessParking': '{'garage': False, 'street...
# 77692   {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 78405   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 81607             {'BusinessAcceptsCreditCards': 'False'}
# 85872   {'BusinessParking': '{'garage': True, 'street'...
# 88219   {'RestaurantsPriceRange2': '3', 'BusinessParki...
# 89357              {'BusinessAcceptsCreditCards': 'True'}
# 89945   {'DriveThru': 'False', 'Ambience': '{'romantic...
# 91435   {'BusinessParking': '{'garage': False, 'street...
# 91500              {'BusinessAcceptsCreditCards': 'True'}
# 98671   {'GoodForKids': 'True', 'RestaurantsGoodForGro...
# 105458  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 109536  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 116290  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 117619  {'BusinessParking': '{'garage': False, 'street...
# 118288  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 120414  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 121673  {'BikeParking': 'True', 'RestaurantsPriceRange...
# 132494                                               None
# 132534  {'RestaurantsReservations': 'False', 'Restaura...
# 133828  {'OutdoorSeating': 'False', 'RestaurantsPriceR...
# 133980             {'BusinessAcceptsCreditCards': 'True'}
# 134901  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 139277  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 142829             {'BusinessAcceptsCreditCards': 'True'}
# 143069  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 151045                           {'GoodForKids': 'False'}
# 152015  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...
# 153190  {'OutdoorSeating': 'True', 'RestaurantsReserva...
# 155664  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 156493                                               None
# 157954  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 161165                                               None
# 163804             {'BusinessAcceptsCreditCards': 'True'}
# 165255  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 168007  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 169862  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 170354  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 172475  {'RestaurantsPriceRange2': '2', 'BikeParking':...
#
# 133980       89030             7    4.5    N Las Vegas            4
# 134901       89081             7    3.0    N Las Vegas            4
# 139277       89108            14    5.0    N Las Vegas            4
# 142829       89147            68    5.0  110 Las Vegas            5
# 143069       89030            33    2.0    N Las Vegas            4
# 151045       89119             4    4.5       La Vegas            7
# 152015       89030            13    3.5   N. Las Vegas            4
# 153190       89031             3    2.5    N Las Vegas            4
# 155664       89032           177    2.0   N. Las Vegas            4
# 156493       89030             3    3.5   N. Las Vegas            4
# 157954       89032             7    2.5    N Las Vegas            4
# 161165       89107             3    2.5     Las  Vegas            7
# 163804       89031            10    4.0    N Las Vegas            4
# 165255       89032             3    3.5    N Las Vegas            4
# 168007       89130            74    2.5  N W Las Vegas            4
# 169862       89103             4    5.0     Las  Vegas            7
# 170354       89030             8    3.5   N. Las Vegas            4
# 172475       89084            23    3.5    N Las Vegas            4
# 178023       89032             3    2.5    N Las Vegas            4
# 179012       89109             5    4.5       Lasvegas            8
# 180746       89031             6    4.5   N. Las Vegas            4
# 186720       89031            12    4.5    N Las Vegas            4
# 188956       89107             3    5.0     Las Vergas            7
#
#         L_levi_dist
# 3993              1
# 12686             3
# 17423             3
# 23849             2
# 28686             1
# 29864             3
# 30998             3
# 39306             2
# 47208             3
# 48752             2
# 49456             3
# 55829             3
# 63321             4
# 65197             4
# 69308             2
# 71027             2
# 74494             1
# 77692             2
# 78405             4
# 81607             2
# 85872             1
# 88219             4
# 89357             1
# 89945             2
# 91435             2
# 91500             2
# 98671             1
# 105458            1
# 109536            3
# 116290            2
# 117619            3
# 118288            2
# 120414            2
# 121673            2
# 132494            2
# 132534            2
# 133828            2
# 133980            2
# 134901            2
# 139277            2
# 142829            4
# 143069            2
# 151045            1
# 152015            3
# 153190            2
# 155664            3
# 156493            3
# 157954            2
# 161165            1
# 163804            2
# 165255            2
# 168007            4
# 169862            1
# 170354            3
# 172475            2
# 178023            2
# 179012            2
# 180746            3
# 186720            2
# 188956            1

# %%
get_levinshtein_distance_city(business_df, 'Henderson', 'city')

# %%
business_df[(business_df['H_levi_dist'] < 4) & (business_df['H_levi_dist'] > 0)]
# Out:
#                                   address  \
# 20195                     9053 S Pecos Rd
# 49811   1000 N Green Valley Pkwy, Ste 440
# 100155                 9955 S Eastern Ave
# 179305         1300 W Sunset Rd, Ste 1537
#
#                                                attributes  \
# 20195   {'AcceptsInsurance': 'True', 'ByAppointmentOnl...
# 49811                                                None
# 100155  {'BusinessParking': '{'garage': False, 'street...
# 179305  {'BusinessParking': '{'garage': False, 'street...
#
#                    business_id  \
# 20195   G3VVtNuIZCYndh3OwoGrKQ
# 49811   M0RU7x_4Tg1ITUQCASFDQw
# 100155  sEIYwtCebPe9QZJfEQ5Pdg
# 179305  UenZP1tN5itN4zUjlu7ztA
#
#                                                categories         city  \
# 20195            Dentists, Health & Medical, Endodontists   Hendserson
# 49811                              Tours, Hotels & Travel    Hnederson
# 100155  Home Services, Grocery, Nurseries & Gardening,...  W Henderson
# 179305  Watch Repair, Shopping, Jewelry Repair, Local ...   Henderston
#
#                                                     hours  is_open   latitude  \
# 20195   {'Monday': '8:0-16:30', 'Tuesday': '8:0-16:30'...        1  36.025225
# 49811   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  36.027507
# 100155  {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...        1  36.007479
# 179305  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...        1  36.067252
#
#          longitude                                name postal_code  \
# 20195  -115.101460                Ryan C Shipp, DMD MS       89074
# 49811  -115.083852                Tours of Distinction       89074
# 100155 -115.117951             Lowe's Home Improvement       89123
# 179305 -115.041219  Fast Fix Jewelry and Watch Repairs       89014
#
#         review_count  stars        city_  N_levi_dist  L_levi_dist  \
# 20195             13    4.5   Hendserson           14            9
# 49811              3    3.5    Hnederson           14            9
# 100155            99    2.5  W Henderson           14           10
# 179305            67    4.0   Henderston           14           10
#
#         H_levi_dist
# 20195             1
# 49811             2
# 100155            2
# 179305            1

# %%
clean_city_name(business_df, 'Henderson', 'city', 4)

# %%
business_df = business_df[(business_df['city'] == 'North Las Vegas') | (business_df['city'] == 'Las Vegas') | (business_df['city'] == 'Henderson')]

# %%
business_df.drop(['city_', 'H_levi_dist', 'L_levi_dist', 'N_levi_dist'], axis = True, inplace = True)

# %%
business_df.city.value_counts()
# Out:
# Las Vegas          29476
# Henderson           4907
# North Las Vegas     1550
# Name: city, dtype: int64

# %%
business_df = business_df.reset_index(drop =True)

# %%
food_related = ['Tacos','Custom Cakes', 'Wine & Spirits', 'Sandwiches', 'Hookah Bars', 'Ice Cream & Frozen Yogurt',
                             'Middle Eastern', 'Gastropubs', 'Chicken Wings','Fast Food','Soup','French',
                             'Tex-Mex','Specialty Food','Persian/Iranian','Wine Bars', 'Hot Dogs','Dive Bars', 'Chinese',
                            'Buffets','Barbeque','Beer Gardens', 'Desserts','Cafes','Vietnamese','Burgers','Fish & Chips',
                             'Southern','Pubs', 'Japanese','Vegan','Thai','Imported Food','Pizza','Canadian (New)','Turkish',
                            'Mexican', 'American (Traditional)','Modern European','Bakeries','Bars','Dim Sum','Ethnic Food',
                            'Seafood', 'Delis','Cajun/Creole','Cupcakes','Vegetarian','Diners','Steakhouses','Irish Pub',
                             'Italian','Tapas Bars','American (New)', 'Food Banks','Breakfast & Brunch','Restaurants', 'Donuts',
                             'Juice Bars & Smoothies','Beer','Caterers','Asian Fusion','Salad','Herbs & Spices','Korean',
                             'Food','Mediterranean','Caribbean','Portuguese','Sushi Bars','Coffee & Tea','Comfort Food']

# %%
def food_filter(x):
    if (x == None):
        return False
    for i in food_related:
        if ( i in x):
            return (True)
    return False    
# function to filter out the categories

# %%
business_df =business_df[business_df.categories.apply(lambda x:food_filter(x))]
# application of the function

# %%
business_df = business_df.reset_index(drop =True)

# %%
establishment_df = pd.read_csv(inspection_rest_url , sep = ';')

# %%
establishment_df.drop(establishment_df.columns[-1], axis = 1, inplace = True)

# %%
# cleaning establishemnt_df
get_levinshtein_distance_city(establishment_df, 'North Las Vegas', 'city_name')

# %%
establishment_df.loc[(establishment_df['N_levi_dist'] < 5) & (establishment_df['N_levi_dist'] > 0), ['city_id', 'city_name']]
# Out:
#        city_id        city_name
# 25119       -1  North LasV EGAS

# %%
clean_city_name(establishment_df, 'North Las Vegas', 'city_name', 5)

# %%
get_levinshtein_distance_city(establishment_df, 'Las Vegas', 'city_name')

# %%
establishment_df.loc[(establishment_df['L_levi_dist'] < 5) & (establishment_df['L_levi_dist'] > 0), ['city_id', 'city_name']]
# Out:
#        city_id     city_name
# 21087       -1      La VeGAS
# 25590       -1      Las VGAS
# 25820       -1  Las Vegas NV
# 25821       -1  Las Vegas NV

# %%
clean_city_name(establishment_df, 'Las Vegas', 'city_name', 5)

# %%
get_levinshtein_distance_city(establishment_df, 'Henderson', 'city_name')

# %%
establishment_df.loc[(establishment_df['H_levi_dist'] < 5) & (establishment_df['H_levi_dist'] > 0), ['city_id', 'city_name']]
# Out:
# Empty DataFrame
# Columns: [city_id, city_name]
# Index: []

# %%
clean_city_name(establishment_df, 'Henderson', 'city_name', 5)

# %%
establishment_df.loc[establishment_df['city_name'] == 'Las Vegas, NV 89103', 'city_name'] = 'Las Vegas'

# %%
establishment_df['city_name'].unique()
# Out:
# array(['Las Vegas', 'Blue Diamond', 'Henderson', 'North Las Vegas',
#        'Boulder City', 'Laughlin', 'Cal-Nev-Ari', 'Sandy Valley',
#        'Searchlight', 'Mesquite', 'Bunkerville', 'Overton', 'Logandale',
#        'Indian Springs', 'Mount Charleston', 'Goodsprings', 'Moapa',
#        'Primm', 'Jean', 'Spring Valley Mtns', 'Salt Lake City',
#        'Coyote Springs', 'St George', 'Shoshone', 'San Francisco',
#        'Honolulu', 'Pahrump', 'Arlington', 'Bakersfield', 'Apple Valley',
#        'Hansen', 'Laguna Hills', 'San Diego', 'Spokane', 'Palm Gardens',
#        'Lodi', 'Summerlin', 'Paradise Valley', 'Beaver Dam', 'MiESQUITE'],
#       dtype=object)

# %%
establishment_df = establishment_df[(establishment_df['city_name'] == 'North Las Vegas') | (establishment_df['city_name'] == 'Las Vegas') | (establishment_df['city_name'] == 'Henderson')]

# %%
establishment_df.loc[establishment_df['city_id'] == -1, ['city_id', 'city_name']]
# Out:
#        city_id        city_name
# 21087       -1        Las Vegas
# 25119       -1  North Las Vegas
# 25590       -1        Las Vegas
# 25820       -1        Las Vegas
# 25821       -1        Las Vegas
# 26020       -1        Las Vegas

# %%
business_df.columns
# Out:
# Index(['address', 'attributes', 'business_id', 'categories', 'city', 'hours',
#        'is_open', 'latitude', 'longitude', 'name', 'postal_code',
#        'review_count', 'stars'],
#       dtype='object')

# %%
b_df_words = []
for  k in business_df.name:
    k = k.lower()
    tokens = word_tokenize(k)
    words = [word for word in tokens if word.isalpha()]
    words = [w for w in words if not w in stop_words]
    b_df_words.extend(words)
# get most common words in the names for business_df

# %%
esta_df_words = []
for  k in establishment_df.location_name:
    k= k.lower()
    tokens = word_tokenize(k)
    words = [word for word in tokens if word.isalpha()]
    words = [w for w in words if not w in stop_words]
    esta_df_words.extend(words)
# get most common words in the names for establishment_df

# %%
pd.Series(b_df_words).value_counts()[:20]
# top 20 business_df name words
# Out:
# bar           494
# cafe          458
# grill         448
# pizza         438
# restaurant    425
# vegas         235
# lounge        227
# taco          221
# kitchen       207
# las           203
# sushi         189
# starbucks     186
# shop          177
# mexican       171
# market        167
# house         161
# el            158
# express       153
# subway        153
# bbq           140
# dtype: int64

# %%
pd.Series(esta_df_words).value_counts()[0:20]
# top 20 establishment_df name words
# Out:
# casino        4599
# hotel         3918
# vegas         1095
# las           1048
# resort        1010
# bar            717
# grill          687
# restaurant     675
# cafe           603
# grand          600
# center         567
# mgm            552
# ice            516
# pizza          488
# school         459
# el             430
# food           421
# deleted        420
# cream          410
# caesars        372
# dtype: int64

# %%
list_remove = ['bar','cafe','grill','casino','restaurant','hotel','resort','kitchen','pizza','lounge','bakery','shop','market']
# list of words to remove

# %%
def clean_text(x):
    temp = str(x)
    temp = temp.lower()
    tokens = word_tokenize(temp)
    words = [word for word in tokens if word.isalpha()]
    words = [w for w in words if not w in stop_words]
    words = [w for w in words if not w in list_remove]
    k= " ".join(words)
    return (k.strip()) 
#cleaning the name,removing punctuations,removing frequent words

# %%
clean_text(business_df.name[6])
# Out:
# 'imperial asian buffet'

# %%
business_df['clean_name'] = business_df.name.apply(lambda x : clean_text(x))

# %%
establishment_df['clean_rest_name'] = establishment_df.restaurant_name.apply(lambda x : clean_text(x))

# %%
establishment_df['clean_loc_name'] = establishment_df.location_name.apply(lambda x : clean_text(x))

# %%
def get_LCS(x,y):
    s = SequenceMatcher(lambda x: x==' ',x,y)
    match = s.find_longest_match(0, len(x), 0, len(y)) 
    if (len(x) >= len(y)):
        min_len = len(y)
    else: min_len = len(x)    
    lcs = x[match.a: match.a + match.size]
    return [lcs,len(lcs),len(lcs)/(min_len+1)]
# fucntion to return LCS,len(LCS),normalized_LCS

# %%
#def get_nearest_list(x,df):
 #   df_filter = df[df.latitude.between(x.latitude -0.001,x.latitude+0.001) & df.longitude.between(x.longitude-0.001,x.longitude+0.001)]
  #  if (df_filter.shape[0] <=10) :
   #     df_filter = df[df.latitude.between(x.latitude -0.01,x.latitude+0.01) & df.longitude.between(x.longitude-0.01,x.longitude+0.01)]
    #df_filter['business_name'] = x['name']
    #df_filter['business_address'] = x['address']
    #df_filter['lev_dist_normalized'] = df_filter['clean_loc_name'].apply(lambda y:editdistance.eval(x['clean_name'],y)/(len(x['clean_name'])+len(y)))
    #df_filter[['LCS','LCS_len','LCS_normal']] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name']),axis =1 ,result_type ='expand')
    #df_filter['LCS_normal'] = df_filter['clean_rest_name'].apply(lambda y : (lcs.llcs(x['clean_name'], y))/(len(x['clean_name'])+len(y)))
    #df_filter = df_filter.sort_values(by=['LCS_normal'],ascending = False)
    #return df_filter[['location_name','clean_rest_name','facility_id','clean_loc_name','address','business_name','business_address','lev_dist_normalized','LCS','LCS_len','LCS_normal']]

# %%
def get_nearest_facid_name(x,df):
    df_filter = df[df['latitude'].between(x['latitude'] -0.001,x['latitude']+0.001) & df['longitude'].between(x['longitude']-0.001,x['longitude']+0.001)]
    if (df_filter.shape[0] <=10) :
        df_filter = df[df.latitude.between(x['latitude'] -0.01,x['latitude']+0.01) & df.longitude.between(x['longitude']-0.01,x['longitude']+0.01)]
    df_filter['business_name'] = x['name']
    df_filter['business_address'] = x['address']
    if df_filter.empty:
        return None   
    df_filter['lev_dist_normalized'] = df_filter['clean_loc_name'].apply(lambda y:editdistance.eval(x['clean_name'],y)/(len(x['clean_name'])+len(y)+1))
    df_filter['LCS'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[0],axis =1 ,result_type ='expand')
    df_filter['LCS_len'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[1],axis =1 ,result_type ='expand')         
    df_filter['LCS_normal'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[2],axis =1 ,result_type ='expand')
    #df_filter['LCS_normal'] = df_filter['clean_rest_name'].apply(lambda y : (lcs.llcs(x['clean_name'], y))/(len(x['clean_name'])+len(y)))
    df_filter = df_filter.sort_values(by=['LCS_normal'],ascending = False)
    ret = df_filter[df_filter.LCS_normal>0.5]
    if ret.empty:
        return None
    ret =ret['facility_id'].unique()
    return ret
# function to return fcaility_ids for each name in business_Df from establishment_df

# %%
get_nearest_facid_name(business_df.iloc[22,],establishment_df)
# Out:
# array(['FA0080177'], dtype=object)

# %%
#k=[]
#for i in range(business_df.shape[0]):
 #   temp = get_nearest_facid_name(business_df.iloc[i,],establishment_df)
  #  k.append(temp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-cabee092d6be> in <module>
#       1 k=[]
#       2 for i in range(business_df.shape[0]):
# ----> 3     temp = get_nearest_facid_name(business_df.iloc[i,],establishment_df)
#       4     k.append(temp)
#
# <ipython-input-71-fe77fdafb53a> in get_nearest_facid_name(x, df)
#      10     df_filter['LCS'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[0],axis =1 ,result_type ='expand')
#      11     df_filter['LCS_len'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[1],axis =1 ,result_type ='expand')
# ---> 12     df_filter['LCS_normal'] = df_filter.apply(lambda y:get_LCS(x['clean_name'],y['clean_loc_name'])[2],axis =1 ,result_type ='expand')
#      13     #df_filter['LCS_normal'] = df_filter['clean_rest_name'].apply(lambda y : (lcs.llcs(x['clean_name'], y))/(len(x['clean_name'])+len(y)))
#      14     df_filter = df_filter.sort_values(by=['LCS_normal'],ascending = False)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3450         # value exception to occur first
#    3451         if len(self):
# -> 3452             self._check_setitem_copy()
#    3453
#    3454     def insert(self, loc, column, value, allow_duplicates=False):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    3244             try:
#    3245                 gc.collect(2)
# -> 3246                 if not gc.get_referents(self._is_copy()):
#    3247                     self._is_copy = None
#    3248                     return
#
# KeyboardInterrupt:

# %%
business_df_key = pd.read_csv('D:/down/business_With_key')
# read already preprocessed file

# %%
business_df_key=business_df_key.drop(columns = 'Unnamed: 0')

# %%
business_df_key.isna().sum()
# Out:
# address          205
# attributes       299
# business_id        0
# categories         0
# city               0
# hours           2514
# is_open            0
# latitude           0
# longitude          0
# name               0
# postal_code       23
# review_count       0
# stars              0
# clean_name       239
# key             5910
# dtype: int64

# %%
business_key_clean=business_df_key.dropna(subset=['key']).reset_index(drop= True)

# %%
temp_test = business_key_clean.key

# %%
temp_test[7]
# Out:
# "['FA0077104' 'FA0084247']"

# %%
temp_test[7].split(' ')
# Out:
# ["['FA0077104'", "'FA0084247']"]

# %%
re.sub("[\[''\]]",'',temp_test[7].split(' ')[0])
# Out:
# 'FA0077104'

# %%
expand_df = pd.DataFrame(columns= business_key_clean.columns )

# %%
expand_df
for i in business_key_clean.shape[0]:
# Out:
# Empty DataFrame
# Columns: [address, attributes, business_id, categories, city, hours, is_open, latitude, longitude, name, postal_code, review_count, stars, clean_name, key]
# Index: []

# %%
establishment_df.columns
# Out:
# Index(['permit_number', 'facility_id', 'owner_id', 'PE', 'restaurant_name',
#        'location_name', 'address', 'latitude', 'longitude', 'city_id',
#        'city_name', 'zip_code', 'nciaa', 'plan_review', 'record_status',
#        'current_grade', 'current_demerits', 'date_current', 'previous_grade',
#        'date_previous', 'search_text', 'city_', 'N_levi_dist', 'L_levi_dist',
#        'H_levi_dist', 'clean_rest_name', 'clean_loc_name'],
#       dtype='object')

# %%
len(k)

# %%
temp=pd.Series(k)

# %%
business_df['key']=temp

# %%
business_df.key.isna().sum()

# %%
business_df.to_csv('D:/down/business_With_key')

# %%
business_df.iloc[11,]['name']

# %%
def get_nearest_dist(x,df):
    dist =1000000000000000000
    name=''
    facility_id=''
    df_filter = df[df.latitude.between(x.latitude -0.001,x.latitude+0.001) & df.longitude.between(x.longitude-0.001,x.longitude+0.001)]
    for i in df_filter.index:
        distance = (df['latitude'][i]-x.latitude)**2 + (df['longitude'][i]-x.longitude)**2
        if(distance<dist ):
            name_in = df['location_name'][i]
            address_in = df['address'][i]
            facility_id = df['location_name'][i]
            dist = distance
    return [name_in,facility_id,address_in,dist]

# %%
def get_nearest_name(x,df):
    lev_dist =1000000000000000000
    name=''
    facility_id=''
    df_filter = df[df.latitude.between(x.latitude -0.001,x.latitude+0.001) & df.longitude.between(x.longitude-0.0005,x.longitude+0.0005)]
    for i in df_filter.index:
        lev_dist_temp = editdistance.eval(x['name'].lower(),df['location_name'][i].lower())
        if(lev_dist_temp<lev_dist ):
            lev_dist = lev_dist_temp
            name_in = df['location_name'][i]
            address_in = df['address'][i]
            facility_id = df['location_name'][i]
            distance = (df['latitude'][i]-x.latitude)**2 + (df['longitude'][i]-x.longitude)**2
    if (lev_dist<20):        
         return [lev_dist,name_in,facility_id,address_in,distance]
    else:
        return [None,None,None,None,None]

# %%
d = get_nearest_list(business_df.iloc[10,],establishment_df)
d

# %%
d[d.restaurant_name.str.contains("bistro",na=False) & d.address.str.contains("",na=False)]

# %%
d[d.location_name.str.contains("metro",na=False) & d.address.str.contains("",na=False)].facility_id.unique()
